# %% [markdown]
# This Notebook filters the mappingbased_literals file for all types that are numbers or dates

# %%
import re
import collections
from utils.myutils import split_triple, save_object

# %%
types_valid = set(['http://www.w3.org/2001/XMLSchema#positiveInteger',
                   'http://www.w3.org/2001/XMLSchema#float',
                   'http://www.w3.org/2001/XMLSchema#integer',
                   'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
                   'http://www.w3.org/2001/XMLSchema#double',
                   'http://www.w3.org/2001/XMLSchema#gYear',
                   'http://www.w3.org/2001/XMLSchema#date',
                   'http://www.w3.org/2001/XMLSchema#gYearMonth'])
types_invalid = set(['http://www.w3.org/1999/02/22-rdf-syntax-ns#langString',
                     'http://www.w3.org/2001/XMLSchema#string',
                     'http://www.w3.org/2001/XMLSchema#boolean',
                     'http://dbpedia.org/datatype/engineConfiguration',
                     'http://dbpedia.org/datatype/valvetrain',
                     'http://dbpedia.org/datatype/fuelType',
                     'http://www.w3.org/2001/XMLSchema#anyURI'])

# %%
file_path_triples = "dbpedia/mappingbased_literals_en.ttl"
file_path_triples_filtered = "dbpedia/mappingbased_literals_en_filtered.ttl"
file_path_owl = "dbpedia/dbpedia_2016-10.owl"

triples_file = open(file_path_triples, 'r', encoding='utf-8')
triples_file_filtered = open(file_path_triples_filtered, 'w', encoding='utf-8')
owl_file = open(file_path_owl, 'r', encoding='utf-8')

relations_valid = set([])
relations_invalid = set([])

relation_type_dict = dict()

relations_cnt = collections.Counter()
types_cnt = collections.Counter()
relations_valid_cnt = collections.Counter()
types_valid_cnt = collections.Counter()

# %%
#Manual Assignment of some non-DBPedia relations - All others will get String assigned!
relations_valid.add('http://www.w3.org/2003/01/geo/wgs84_pos#lat')
relation_type_dict['http://www.w3.org/2003/01/geo/wgs84_pos#lat'] = 'http://www.w3.org/2001/XMLSchema#float'
relations_valid.add('http://www.w3.org/2003/01/geo/wgs84_pos#long')
relation_type_dict['http://www.w3.org/2003/01/geo/wgs84_pos#long'] = 'http://www.w3.org/2001/XMLSchema#float'

# %%
regex_xml_tag = re.compile('<rdfs:range rdf:resource=[^>]*/>')
regex_resource = re.compile('rdf:resource=".*"/>')

#Look up the type of an unknown relations that is neither in relations_valid nor in relations_invalid
def check_new_relation(relation):
    #print(relation)
    search_term = 'rdf:about="' + relation + '"'
    owl_file.seek(0)
    for line in owl_file:
        if search_term in line:
            #Read next line
            range_line = owl_file.readline()
            #print(str(relation) + " found in line " + line)
            #print("Assuming range in line " + range_line)
            
            try:
                rdfs_range_tag = regex_xml_tag.search(range_line)[0]
            except TypeError:
                range_line = owl_file.readline()
                try:
                    rdfs_range_tag = regex_xml_tag.search(range_line)[0]
                    print("WARNING! Could not find in-line type for relation " + relation)
                    print("Found type in the next line. Check whether this is correct!")
                except TypeError:
                    print("ERROR! Could not find a type for relation " + relation)
                    continue
            
            try:
                regex_xml_tag.search(range_line)[1]
            except IndexError:
                relation_range = regex_resource.search(rdfs_range_tag)[0][14:-3]
                
                relation_type_dict[relation] = relation_range
                
                if relation_range in types_valid:
                    #print("Relation " + relation + " has type " + relation_range + " and is therfore valid.")
                    relations_valid.add(relation)
                elif relation_range in types_invalid:
                    #print("Relation " + relation + " has type " + relation_range + " and is therfore invalid.")
                    relations_invalid.add(relation)
                else:
                    print("WARNING! Relation " + relation + " has unknown type " + relation_range)
                
                return
            print("ERROR! Multiple Findings! Second Finding: " + regex_xml_tag.search(range_line)[1])
    
    print("WARNING! Could not find a type for relation " + relation + "! Assuming String from now on!")
    relations_invalid.add(relation)
    relation_type_dict[relation] = 'http://www.w3.org/2001/XMLSchema#string'

# %%
i = 0
# Loop over all existing Triples
for line in triples_file:
    i += 1
    
    #Skip comment lines and empty lines
    if line[:1] == '#' or len(line) == 0:
        continue
    
    #Split triple correctly into 3-array
    try:
        triple = split_triple(line)
    except ValueError:
        print("ValueError: Split not possible: " + line)
        continue
    
    if triple[1][1:-1] not in relations_valid and triple[1][1:-1] not in relations_invalid:
        check_new_relation(triple[1][1:-1])
    
    relations_cnt[triple[1][1:-1]] += 1
    types_cnt[relation_type_dict[triple[1][1:-1]]] += 1
    
    if triple[1][1:-1] in relations_invalid:
        #print(triple[1] + " is invalid. Ignored.")
        continue
        
    if triple[1][1:-1] in relations_valid:
        #print(triple[1] + " is valid.")
        triples_file_filtered.write(line)
        relations_valid_cnt[triple[1][1:-1]] += 1
        types_valid_cnt[relation_type_dict[triple[1][1:-1]]] += 1
    else:
        #print(triple[1] + " is invalid. Ignored.")
        print("ERROR! Tuple not valid or invalid!")
    
    if i % 1000 == 0:
        print(str(i) + " entries processed")
        
    #if i > 10000:
    #    break

triples_file.close()
triples_file_filtered.close()
owl_file.close()
# Out:
# WARNING! Could not find a type for relation http://xmlns.com/foaf/0.1/name! Assuming String from now on!
# WARNING! Could not find a type for relation http://purl.org/dc/elements/1.1/publisher! Assuming String from now on!
# WARNING! Could not find a type for relation http://purl.org/dc/elements/1.1/type! Assuming String from now on!
# WARNING! Could not find a type for relation http://xmlns.com/foaf/0.1/nick! Assuming String from now on!
# WARNING! Could not find a type for relation http://xmlns.com/foaf/0.1/givenName! Assuming String from now on!
# 1000 entries processed
# 2000 entries processed
# 4000 entries processed
# 5000 entries processed
# 8000 entries processed
# 12000 entries processed
# 18000 entries processed
# 20000 entries processed
# 23000 entries processed
# 25000 entries processed
# 27000 entries processed
# 31000 entries processed
# 33000 entries processed
# 34000 entries processed
# 35000 entries processed
# 36000 entries processed
# 42000 entries processed
# 46000 entries processed
# 47000 entries processed
# 49000 entries processed
# 50000 entries processed
# 51000 entries processed
# 53000 entries processed
# 54000 entries processed
# 58000 entries processed
# 59000 entries processed
# 62000 entries processed
# 66000 entries processed
# 67000 entries processed
# 71000 entries processed
# 75000 entries processed
# 78000 entries processed
# 81000 entries processed
# 84000 entries processed
# 85000 entries processed
# 90000 entries processed
# 98000 entries processed
# 101000 entries processed
# 102000 entries processed
# 103000 entries processed
# 104000 entries processed
# 105000 entries processed
# 106000 entries processed
# 107000 entries processed
# 109000 entries processed
# 110000 entries processed
# 111000 entries processed
# 112000 entries processed
# 114000 entries processed
# 116000 entries processed
# 117000 entries processed
# 118000 entries processed
# 119000 entries processed
# 120000 entries processed
# 121000 entries processed
# 122000 entries processed
# 123000 entries processed
# 124000 entries processed
# 125000 entries processed
# 126000 entries processed
# 127000 entries processed
# 128000 entries processed
# 129000 entries processed
# 130000 entries processed
# 132000 entries processed
# WARNING! Could not find a type for relation http://purl.org/dc/elements/1.1/description! Assuming String from now on!
# 134000 entries processed
# 136000 entries processed
# 137000 entries processed
# 139000 entries processed
# 140000 entries processed
# 141000 entries processed
# 142000 entries processed
# 143000 entries processed
# 145000 entries processed
# 146000 entries processed
# 149000 entries processed
# 151000 entries processed
# 152000 entries processed
# 153000 entries processed
# 156000 entries processed
# 158000 entries processed
# 159000 entries processed
# 161000 entries processed
# 162000 entries processed
# 163000 entries processed
# 165000 entries processed
# 166000 entries processed
# 168000 entries processed
# 169000 entries processed
# 170000 entries processed
# 172000 entries processed
# 173000 entries processed
# 174000 entries processed
# 175000 entries processed
# 177000 entries processed
# 178000 entries processed
# 181000 entries processed
# 182000 entries processed
# 183000 entries processed
# 184000 entries processed
# 186000 entries processed
# 189000 entries processed
# 190000 entries processed
# 192000 entries processed
# 193000 entries processed
# 194000 entries processed
# 195000 entries processed
# 198000 entries processed
# 200000 entries processed
# 202000 entries processed
# 203000 entries processed
# 205000 entries processed
# 207000 entries processed
# 209000 entries processed
# 210000 entries processed
# 212000 entries processed
# 218000 entries processed
# 219000 entries processed
# 220000 entries processed
# 222000 entries processed
# 223000 entries processed
# 224000 entries processed
# 226000 entries processed
# 227000 entries processed
# 228000 entries processed
# 230000 entries processed
# 232000 entries processed
# 233000 entries processed
# 237000 entries processed
# 238000 entries processed
# 239000 entries processed
# 243000 entries processed
# 248000 entries processed
# 250000 entries processed
# 251000 entries processed
# 255000 entries processed
# 256000 entries processed
# 259000 entries processed
# 260000 entries processed
# 261000 entries processed
# 263000 entries processed
# 264000 entries processed
# 265000 entries processed
# 266000 entries processed
# 268000 entries processed
# 269000 entries processed
# 270000 entries processed
# 271000 entries processed
# 272000 entries processed
# 273000 entries processed
# 274000 entries processed
# 276000 entries processed
# 277000 entries processed
# 279000 entries processed
# 282000 entries processed
# 283000 entries processed
# 285000 entries processed
# 286000 entries processed
# 288000 entries processed
# 289000 entries processed
# 291000 entries processed
# 292000 entries processed
# 295000 entries processed
# 297000 entries processed
# 299000 entries processed
# 300000 entries processed
# 302000 entries processed
# 303000 entries processed
# 304000 entries processed
# 305000 entries processed
# 306000 entries processed
# 308000 entries processed
# 309000 entries processed
# 310000 entries processed
# 311000 entries processed
# 312000 entries processed
# 314000 entries processed
# 315000 entries processed
# 317000 entries processed
# 318000 entries processed
# 319000 entries processed
# 320000 entries processed
# 321000 entries processed
# 323000 entries processed
# 324000 entries processed
# 326000 entries processed
# 327000 entries processed
# 328000 entries processed
# 330000 entries processed
# 333000 entries processed
# 335000 entries processed
# 336000 entries processed
# 338000 entries processed
# 339000 entries processed
# 343000 entries processed
# 344000 entries processed
# 346000 entries processed
# 347000 entries processed
# 348000 entries processed
# 350000 entries processed
# 353000 entries processed
# 355000 entries processed
# 356000 entries processed
# 357000 entries processed
# 359000 entries processed
# 360000 entries processed
# 361000 entries processed
# 364000 entries processed
# 365000 entries processed
# 366000 entries processed
# 367000 entries processed
# 368000 entries processed
# 369000 entries processed
# 370000 entries processed
# 371000 entries processed
# 374000 entries processed
# 376000 entries processed
# 377000 entries processed
# 379000 entries processed
# 384000 entries processed
# 385000 entries processed
# 386000 entries processed
# 388000 entries processed
# 389000 entries processed
# 392000 entries processed
# 400000 entries processed
# 401000 entries processed
# 402000 entries processed
# 403000 entries processed
# 404000 entries processed
# 405000 entries processed
# 406000 entries processed
# 411000 entries processed
# 413000 entries processed
# 414000 entries processed
# 415000 entries processed
# 417000 entries processed
# 420000 entries processed
# 421000 entries processed
# 423000 entries processed
# 424000 entries processed
# 425000 entries processed
# 426000 entries processed
# 427000 entries processed
# 430000 entries processed
# 431000 entries processed
# 432000 entries processed
# 434000 entries processed
# 435000 entries processed
# 436000 entries processed
# 438000 entries processed
# 439000 entries processed
# 441000 entries processed
# 442000 entries processed
# 443000 entries processed
# 445000 entries processed
# 447000 entries processed
# 448000 entries processed
# 450000 entries processed
# 452000 entries processed
# 455000 entries processed
# 458000 entries processed
# 460000 entries processed
# 461000 entries processed
# 462000 entries processed
# 463000 entries processed
# 467000 entries processed
# 468000 entries processed
# 469000 entries processed
# 475000 entries processed
# 476000 entries processed
# 479000 entries processed
# 480000 entries processed
# 481000 entries processed
# 483000 entries processed
# 484000 entries processed
# 485000 entries processed
# 488000 entries processed
# 489000 entries processed
# 490000 entries processed
# 492000 entries processed
# 493000 entries processed
# 494000 entries processed
# 498000 entries processed
# 499000 entries processed
# 500000 entries processed
# 501000 entries processed
# 502000 entries processed
# 503000 entries processed
# 505000 entries processed
# 506000 entries processed
# 507000 entries processed
# 509000 entries processed
# 510000 entries processed
# 512000 entries processed
# 513000 entries processed
# 515000 entries processed
# 516000 entries processed
# 517000 entries processed
# 518000 entries processed
# 519000 entries processed
# 521000 entries processed
# 522000 entries processed
# 525000 entries processed
# 526000 entries processed
# 527000 entries processed
# 530000 entries processed
# 531000 entries processed
# 532000 entries processed
# 534000 entries processed
# 537000 entries processed
# 539000 entries processed
# 540000 entries processed
# 541000 entries processed
# 542000 entries processed
# 543000 entries processed
# 544000 entries processed
# 545000 entries processed
# 549000 entries processed
# 550000 entries processed
# 551000 entries processed
# 552000 entries processed
# 553000 entries processed
# 554000 entries processed
# 556000 entries processed
# 557000 entries processed
# 558000 entries processed
# 562000 entries processed
# 568000 entries processed
# 570000 entries processed
# 571000 entries processed
# 572000 entries processed
# 573000 entries processed
# 574000 entries processed
# 578000 entries processed
# 579000 entries processed
# 581000 entries processed
# 582000 entries processed
# 583000 entries processed
# 585000 entries processed
# 587000 entries processed
# 588000 entries processed
# 594000 entries processed
# 596000 entries processed
# 597000 entries processed
# 598000 entries processed
# 603000 entries processed
# 606000 entries processed
# 608000 entries processed
# 614000 entries processed
# 615000 entries processed
# 617000 entries processed
# 618000 entries processed
# 619000 entries processed
# 620000 entries processed
# 622000 entries processed
# 628000 entries processed
# 631000 entries processed
# 632000 entries processed
# 633000 entries processed
# 634000 entries processed
# 637000 entries processed
# 638000 entries processed
# 639000 entries processed
# WARNING! Could not find in-line type for relation http://dbpedia.org/ontology/sudocId
# Found type in the next line. Check whether this is correct!
# 650000 entries processed
# 651000 entries processed
# 654000 entries processed
# 658000 entries processed
# 659000 entries processed
# 664000 entries processed
# 669000 entries processed
# 672000 entries processed
# 673000 entries processed
# 675000 entries processed
# 676000 entries processed
# 677000 entries processed
# 678000 entries processed
# 681000 entries processed
# 682000 entries processed
# 684000 entries processed
# 687000 entries processed
# 688000 entries processed
# 690000 entries processed
# 691000 entries processed
# 692000 entries processed
# 695000 entries processed
# 696000 entries processed
# 697000 entries processed
# 698000 entries processed
# 702000 entries processed
# 704000 entries processed
# 707000 entries processed
# 708000 entries processed
# 713000 entries processed
# 714000 entries processed
# 715000 entries processed
# 716000 entries processed
# 717000 entries processed
# 720000 entries processed
# 721000 entries processed
# 723000 entries processed
# 724000 entries processed
# 725000 entries processed
# 726000 entries processed
# 727000 entries processed
# 732000 entries processed
# 733000 entries processed
# 734000 entries processed
# 735000 entries processed
# 736000 entries processed
# 737000 entries processed
# 740000 entries processed
# 743000 entries processed
# 745000 entries processed
# 748000 entries processed
# 749000 entries processed
# 751000 entries processed
# 752000 entries processed
# 757000 entries processed
# 758000 entries processed
# 759000 entries processed
# 762000 entries processed
# 764000 entries processed
# 765000 entries processed
# 767000 entries processed
# 772000 entries processed
# 775000 entries processed
# 777000 entries processed
# 779000 entries processed
# 782000 entries processed
# 783000 entries processed
# 784000 entries processed
# 785000 entries processed
# 791000 entries processed
# 792000 entries processed
# 794000 entries processed
# 795000 entries processed
# 797000 entries processed
# 799000 entries processed
# 804000 entries processed
# 806000 entries processed
# 807000 entries processed
# 811000 entries processed
# 813000 entries processed
# 815000 entries processed
# 817000 entries processed
# 821000 entries processed
# 822000 entries processed
# 824000 entries processed
# 828000 entries processed
# 831000 entries processed
# 835000 entries processed
# 837000 entries processed
# 839000 entries processed
# 840000 entries processed
# 842000 entries processed
# 844000 entries processed
# 845000 entries processed
# 846000 entries processed
# 849000 entries processed
# 850000 entries processed
# 851000 entries processed
# 853000 entries processed
# 859000 entries processed
# 862000 entries processed
# 864000 entries processed
# 868000 entries processed
# 870000 entries processed
# 871000 entries processed
# 875000 entries processed
# 878000 entries processed
# 881000 entries processed
# 884000 entries processed
# 887000 entries processed
# 888000 entries processed
# 889000 entries processed
# 890000 entries processed
# 891000 entries processed
# 897000 entries processed
# 898000 entries processed
# 900000 entries processed
# 902000 entries processed
# 904000 entries processed
# 905000 entries processed
# 906000 entries processed
# 908000 entries processed
# 909000 entries processed
# 913000 entries processed
# 914000 entries processed
# 915000 entries processed
# 919000 entries processed
# 920000 entries processed
# 922000 entries processed
# 925000 entries processed
# 927000 entries processed
# 928000 entries processed
# 930000 entries processed
# 936000 entries processed
# 938000 entries processed
# 940000 entries processed
# 941000 entries processed
# 942000 entries processed
# 945000 entries processed
# 949000 entries processed
# 953000 entries processed
# 955000 entries processed
# 957000 entries processed
# 959000 entries processed
# 962000 entries processed
# 963000 entries processed
# 966000 entries processed
# 967000 entries processed
# 972000 entries processed
# 973000 entries processed
# 974000 entries processed
# 975000 entries processed
# 979000 entries processed
# 980000 entries processed
# 988000 entries processed
# 989000 entries processed
# 996000 entries processed
# 997000 entries processed
# 999000 entries processed
# 1002000 entries processed
# 1005000 entries processed
# 1007000 entries processed
# 1008000 entries processed
# 1011000 entries processed
# 1012000 entries processed
# 1014000 entries processed
# 1015000 entries processed
# 1020000 entries processed
# 1021000 entries processed
# 1023000 entries processed
# 1026000 entries processed
# 1028000 entries processed
# 1029000 entries processed
# 1030000 entries processed
# 1031000 entries processed
# 1034000 entries processed
# 1037000 entries processed
# 1039000 entries processed
# 1042000 entries processed
# 1043000 entries processed
# 1045000 entries processed
# 1046000 entries processed
# 1049000 entries processed
# 1050000 entries processed
# 1051000 entries processed
# 1052000 entries processed
# 1053000 entries processed
# 1054000 entries processed
# 1055000 entries processed
# 1058000 entries processed
# 1059000 entries processed
# 1060000 entries processed
# 1061000 entries processed
# 1063000 entries processed
# 1064000 entries processed
# 1070000 entries processed
# 1071000 entries processed
# 1072000 entries processed
# 1073000 entries processed
# 1076000 entries processed
# 1083000 entries processed
# 1085000 entries processed
# 1086000 entries processed
# 1087000 entries processed
# 1088000 entries processed
# 1091000 entries processed
# 1093000 entries processed
# 1094000 entries processed
# 1095000 entries processed
# 1097000 entries processed
# 1101000 entries processed
# 1105000 entries processed
# 1107000 entries processed
# 1110000 entries processed
# 1111000 entries processed
# 1113000 entries processed
# 1116000 entries processed
# 1118000 entries processed
# 1119000 entries processed
# 1120000 entries processed
# 1123000 entries processed
# 1124000 entries processed
# 1128000 entries processed
# 1129000 entries processed
# 1130000 entries processed
# 1131000 entries processed
# 1133000 entries processed
# 1134000 entries processed
# 1135000 entries processed
# 1136000 entries processed
# 1138000 entries processed
# 1139000 entries processed
# 1141000 entries processed
# 1145000 entries processed
# 1147000 entries processed
# 1150000 entries processed
# 1153000 entries processed
# 1157000 entries processed
# 1161000 entries processed
# 1164000 entries processed
# 1165000 entries processed
# 1168000 entries processed
# 1169000 entries processed
# 1171000 entries processed
# 1174000 entries processed
# 1176000 entries processed
# 1177000 entries processed
# 1178000 entries processed
# 1179000 entries processed
# 1182000 entries processed
# 1187000 entries processed
# 1189000 entries processed
# 1190000 entries processed
# 1191000 entries processed
# 1192000 entries processed
# 1193000 entries processed
# 1194000 entries processed
# 1196000 entries processed
# 1197000 entries processed
# 1200000 entries processed
# 1201000 entries processed
# 1208000 entries processed
# 1209000 entries processed
# 1210000 entries processed
# 1211000 entries processed
# 1215000 entries processed
# 1216000 entries processed
# 1217000 entries processed
# 1219000 entries processed
# 1220000 entries processed
# 1223000 entries processed
# 1225000 entries processed
# 1226000 entries processed
# 1227000 entries processed
# 1229000 entries processed
# 1234000 entries processed
# 1235000 entries processed
# 1238000 entries processed
# 1240000 entries processed
# 1241000 entries processed
# 1243000 entries processed
# 1244000 entries processed
# 1248000 entries processed
# 1251000 entries processed
# 1252000 entries processed
# 1256000 entries processed
# 1258000 entries processed
# 1261000 entries processed
# 1262000 entries processed
# 1264000 entries processed
# 1265000 entries processed
# 1270000 entries processed
# 1271000 entries processed
# 1272000 entries processed
# 1273000 entries processed
# 1274000 entries processed
# 1275000 entries processed
# 1278000 entries processed
# 1279000 entries processed
# 1280000 entries processed
# 1281000 entries processed
# 1284000 entries processed
# 1285000 entries processed
# 1286000 entries processed
# 1287000 entries processed
# 1289000 entries processed
# 1291000 entries processed
# 1293000 entries processed
# 1295000 entries processed
# 1298000 entries processed
# 1301000 entries processed
# 1302000 entries processed
# 1303000 entries processed
# 1305000 entries processed
# 1306000 entries processed
# 1307000 entries processed
# 1313000 entries processed
# 1314000 entries processed
# 1316000 entries processed
# 1319000 entries processed
# 1320000 entries processed
# 1321000 entries processed
# 1322000 entries processed
# 1326000 entries processed
# 1330000 entries processed
# 1332000 entries processed
# 1333000 entries processed
# 1337000 entries processed
# 1344000 entries processed
# 1345000 entries processed
# 1346000 entries processed
# 1348000 entries processed
# 1351000 entries processed
# 1352000 entries processed
# 1353000 entries processed
# 1356000 entries processed
# 1359000 entries processed
# 1360000 entries processed
# 1361000 entries processed
# 1369000 entries processed
# 1372000 entries processed
# 1373000 entries processed
# 1374000 entries processed
# 1376000 entries processed
# 1377000 entries processed
# 1378000 entries processed
# 1380000 entries processed
# 1381000 entries processed
# 1382000 entries processed
# 1383000 entries processed
# 1384000 entries processed
# 1385000 entries processed
# 1386000 entries processed
# 1388000 entries processed
# 1395000 entries processed
# 1396000 entries processed
# 1398000 entries processed
# 1401000 entries processed
# 1402000 entries processed
# 1403000 entries processed
# 1404000 entries processed
# 1405000 entries processed
# 1410000 entries processed
# 1411000 entries processed
# 1412000 entries processed
# 1413000 entries processed
# 1415000 entries processed
# 1417000 entries processed
# 1419000 entries processed
# 1420000 entries processed
# 1421000 entries processed
# 1422000 entries processed
# 1423000 entries processed
# 1425000 entries processed
# 1426000 entries processed
# 1427000 entries processed
# 1429000 entries processed
# 1430000 entries processed
# 1432000 entries processed
# 1433000 entries processed
# 1434000 entries processed
# 1435000 entries processed
# 1437000 entries processed
# 1441000 entries processed
# 1444000 entries processed
# 1446000 entries processed
# 1448000 entries processed
# 1451000 entries processed
# 1452000 entries processed
# 1454000 entries processed
# 1456000 entries processed
# 1457000 entries processed
# 1458000 entries processed
# 1459000 entries processed
# 1461000 entries processed
# 1462000 entries processed
# 1464000 entries processed
# 1466000 entries processed
# 1468000 entries processed
# 1469000 entries processed
# 1470000 entries processed
# 1472000 entries processed
# 1473000 entries processed
# 1474000 entries processed
# 1475000 entries processed
# 1479000 entries processed
# 1481000 entries processed
# 1482000 entries processed
# 1484000 entries processed
# 1485000 entries processed
# 1486000 entries processed
# 1487000 entries processed
# 1488000 entries processed
# 1492000 entries processed
# 1493000 entries processed
# 1495000 entries processed
# 1500000 entries processed
# 1503000 entries processed
# 1505000 entries processed
# 1506000 entries processed
# 1510000 entries processed
# 1512000 entries processed
# 1515000 entries processed
# 1519000 entries processed
# 1522000 entries processed
# 1523000 entries processed
# 1524000 entries processed
# 1527000 entries processed
# 1528000 entries processed
# 1529000 entries processed
# 1531000 entries processed
# 1533000 entries processed
# 1534000 entries processed
# 1535000 entries processed
# 1536000 entries processed
# 1537000 entries processed
# 1538000 entries processed
# 1539000 entries processed
# 1540000 entries processed
# 1541000 entries processed
# 1542000 entries processed
# 1544000 entries processed
# 1546000 entries processed
# 1549000 entries processed
# 1550000 entries processed
# 1553000 entries processed
# 1557000 entries processed
# 1558000 entries processed
# 1559000 entries processed
# 1560000 entries processed
# 1561000 entries processed
# 1564000 entries processed
# 1565000 entries processed
# 1566000 entries processed
# 1567000 entries processed
# 1569000 entries processed
# 1571000 entries processed
# 1577000 entries processed
# 1578000 entries processed
# 1579000 entries processed
# 1581000 entries processed
# 1582000 entries processed
# 1583000 entries processed
# 1584000 entries processed
# 1585000 entries processed
# 1588000 entries processed
# 1589000 entries processed
# 1590000 entries processed
# 1591000 entries processed
# 1592000 entries processed
# 1594000 entries processed
# WARNING! Could not find in-line type for relation http://dbpedia.org/ontology/ulanId
# Found type in the next line. Check whether this is correct!
# 1595000 entries processed
# 1596000 entries processed
# 1597000 entries processed
# 1600000 entries processed
# 1602000 entries processed
# 1603000 entries processed
# 1604000 entries processed
# 1608000 entries processed
# 1613000 entries processed
# 1614000 entries processed
# 1615000 entries processed
# 1616000 entries processed
# 1617000 entries processed
# 1619000 entries processed
# 1620000 entries processed
# 1621000 entries processed
# 1622000 entries processed
# 1623000 entries processed
# 1624000 entries processed
# 1629000 entries processed
# 1630000 entries processed
# 1631000 entries processed
# 1632000 entries processed
# 1633000 entries processed
# 1635000 entries processed
# 1636000 entries processed
# 1649000 entries processed
# 1651000 entries processed
# 1653000 entries processed
# 1655000 entries processed
# 1658000 entries processed
# 1662000 entries processed
# 1665000 entries processed
# 1666000 entries processed
# 1667000 entries processed
# 1672000 entries processed
# 1675000 entries processed
# 1676000 entries processed
# 1677000 entries processed
# 1679000 entries processed
# 1680000 entries processed
# 1682000 entries processed
# 1685000 entries processed
# 1686000 entries processed
# 1688000 entries processed
# 1689000 entries processed
# 1691000 entries processed
# 1692000 entries processed
# 1693000 entries processed
# 1694000 entries processed
# 1698000 entries processed
# 1699000 entries processed
# 1702000 entries processed
# 1707000 entries processed
# 1710000 entries processed
# 1711000 entries processed
# 1712000 entries processed
# 1713000 entries processed
# 1714000 entries processed
# 1717000 entries processed
# 1720000 entries processed
# 1721000 entries processed
# 1722000 entries processed
# 1726000 entries processed
# 1728000 entries processed
# 1729000 entries processed
# 1731000 entries processed
# 1732000 entries processed
# 1733000 entries processed
# 1735000 entries processed
# 1736000 entries processed
# 1737000 entries processed
# 1744000 entries processed
# 1745000 entries processed
# 1746000 entries processed
# 1747000 entries processed
# 1750000 entries processed
# 1754000 entries processed
# 1755000 entries processed
# 1756000 entries processed
# 1759000 entries processed
# 1761000 entries processed
# 1762000 entries processed
# 1763000 entries processed
# 1764000 entries processed
# 1765000 entries processed
# 1769000 entries processed
# 1771000 entries processed
# 1776000 entries processed
# 1777000 entries processed
# 1779000 entries processed
# 1781000 entries processed
# 1783000 entries processed
# 1785000 entries processed
# 1786000 entries processed
# 1787000 entries processed
# 1789000 entries processed
# 1790000 entries processed
# 1791000 entries processed
# 1798000 entries processed
# 1799000 entries processed
# 1800000 entries processed
# 1801000 entries processed
# 1803000 entries processed
# 1805000 entries processed
# 1808000 entries processed
# 1810000 entries processed
# 1811000 entries processed
# 1815000 entries processed
# 1816000 entries processed
# 1817000 entries processed
# 1818000 entries processed
# 1820000 entries processed
# 1821000 entries processed
# 1823000 entries processed
# 1827000 entries processed
# 1829000 entries processed
# 1830000 entries processed
# 1831000 entries processed
# 1832000 entries processed
# 1834000 entries processed
# 1836000 entries processed
# 1837000 entries processed
# 1838000 entries processed
# 1839000 entries processed
# 1844000 entries processed
# 1845000 entries processed
# 1847000 entries processed
# 1849000 entries processed
# 1851000 entries processed
# 1852000 entries processed
# 1855000 entries processed
# 1856000 entries processed
# 1858000 entries processed
# 1861000 entries processed
# 1863000 entries processed
# 1866000 entries processed
# 1867000 entries processed
# 1870000 entries processed
# 1871000 entries processed
# 1872000 entries processed
# 1874000 entries processed
# 1879000 entries processed
# 1880000 entries processed
# 1882000 entries processed
# 1885000 entries processed
# 1887000 entries processed
# 1891000 entries processed
# 1894000 entries processed
# 1898000 entries processed
# 1901000 entries processed
# 1902000 entries processed
# 1904000 entries processed
# 1909000 entries processed
# 1911000 entries processed
# 1912000 entries processed
# 1914000 entries processed
# 1915000 entries processed
# 1916000 entries processed
# 1917000 entries processed
# 1918000 entries processed
# 1919000 entries processed
# 1922000 entries processed
# 1925000 entries processed
# 1926000 entries processed
# 1927000 entries processed
# 1928000 entries processed
# 1929000 entries processed
# 1931000 entries processed
# 1935000 entries processed
# 1936000 entries processed
# 1937000 entries processed
# 1939000 entries processed
# 1940000 entries processed
# 1942000 entries processed
# 1943000 entries processed
# 1950000 entries processed
# 1952000 entries processed
# 1954000 entries processed
# 1958000 entries processed
# 1963000 entries processed
# 1964000 entries processed
# 1967000 entries processed
# 1969000 entries processed
# 1972000 entries processed
# 1973000 entries processed
# 1974000 entries processed
# 1976000 entries processed
# 1978000 entries processed
# 1979000 entries processed
# 1980000 entries processed
# 1983000 entries processed
# 1987000 entries processed
# 1988000 entries processed
# 1990000 entries processed
# 1994000 entries processed
# 1998000 entries processed
# 2000000 entries processed
# 2001000 entries processed
# 2002000 entries processed
# 2003000 entries processed
# 2004000 entries processed
# 2008000 entries processed
# 2009000 entries processed
# 2010000 entries processed
# 2011000 entries processed
# 2013000 entries processed
# 2015000 entries processed
# 2016000 entries processed
# 2019000 entries processed
# 2020000 entries processed
# 2021000 entries processed
# 2022000 entries processed
# 2023000 entries processed
# 2024000 entries processed
# 2026000 entries processed
# 2027000 entries processed
# 2029000 entries processed
# 2030000 entries processed
# 2031000 entries processed
# 2034000 entries processed
# 2036000 entries processed
# 2038000 entries processed
# 2040000 entries processed
# 2042000 entries processed
# 2044000 entries processed
# 2045000 entries processed
# 2047000 entries processed
# 2054000 entries processed
# 2055000 entries processed
# 2056000 entries processed
# 2060000 entries processed
# 2061000 entries processed
# 2063000 entries processed
# 2066000 entries processed
# 2067000 entries processed
# 2068000 entries processed
# 2069000 entries processed
# 2072000 entries processed
# 2073000 entries processed
# 2074000 entries processed
# 2077000 entries processed
# 2085000 entries processed
# 2087000 entries processed
# 2090000 entries processed
# 2091000 entries processed
# 2092000 entries processed
# 2094000 entries processed
# 2095000 entries processed
# 2096000 entries processed
# WARNING! Could not find a type for relation http://xmlns.com/foaf/0.1/familyName! Assuming String from now on!
# 2098000 entries processed
# 2100000 entries processed
# 2101000 entries processed
# 2103000 entries processed
# 2104000 entries processed
# 2105000 entries processed
# 2106000 entries processed
# 2109000 entries processed
# 2112000 entries processed
# 2116000 entries processed
# 2117000 entries processed
# 2118000 entries processed
# 2121000 entries processed
# 2124000 entries processed
# 2125000 entries processed
# 2133000 entries processed
# 2134000 entries processed
# 2138000 entries processed
# 2139000 entries processed
# 2140000 entries processed
# 2141000 entries processed
# 2144000 entries processed
# 2145000 entries processed
# 2147000 entries processed
# 2149000 entries processed
# 2151000 entries processed
# 2152000 entries processed
# 2154000 entries processed
# 2155000 entries processed
# 2156000 entries processed
# 2159000 entries processed
# 2162000 entries processed
# 2163000 entries processed
# 2166000 entries processed
# 2170000 entries processed
# 2172000 entries processed
# 2173000 entries processed
# 2174000 entries processed
# 2176000 entries processed
# 2179000 entries processed
# 2181000 entries processed
# 2185000 entries processed
# 2188000 entries processed
# 2189000 entries processed
# 2190000 entries processed
# 2191000 entries processed
# 2193000 entries processed
# 2197000 entries processed
# 2200000 entries processed
# 2202000 entries processed
# 2204000 entries processed
# 2206000 entries processed
# 2208000 entries processed
# 2210000 entries processed
# 2212000 entries processed
# 2215000 entries processed
# 2216000 entries processed
# 2218000 entries processed
# 2220000 entries processed
# 2221000 entries processed
# 2223000 entries processed
# 2226000 entries processed
# 2227000 entries processed
# 2228000 entries processed
# 2230000 entries processed
# 2231000 entries processed
# 2232000 entries processed
# 2235000 entries processed
# 2239000 entries processed
# 2240000 entries processed
# 2241000 entries processed
# 2244000 entries processed
# 2248000 entries processed
# 2249000 entries processed
# 2250000 entries processed
# 2253000 entries processed
# 2254000 entries processed
# 2257000 entries processed
# 2259000 entries processed
# 2260000 entries processed
# 2261000 entries processed
# 2262000 entries processed
# 2264000 entries processed
# 2265000 entries processed
# 2266000 entries processed
# 2270000 entries processed
# 2271000 entries processed
# 2272000 entries processed
# 2275000 entries processed
# 2278000 entries processed
# 2280000 entries processed
# 2281000 entries processed
# 2285000 entries processed
# 2289000 entries processed
# 2290000 entries processed
# 2293000 entries processed
# 2295000 entries processed
# 2296000 entries processed
# 2298000 entries processed
# 2300000 entries processed
# 2302000 entries processed
# 2303000 entries processed
# 2305000 entries processed
# 2309000 entries processed
# 2310000 entries processed
# 2311000 entries processed
# 2313000 entries processed
# 2315000 entries processed
# 2318000 entries processed
# 2319000 entries processed
# 2320000 entries processed
# 2321000 entries processed
# 2324000 entries processed
# 2325000 entries processed
# 2327000 entries processed
# 2328000 entries processed
# 2329000 entries processed
# 2333000 entries processed
# 2334000 entries processed
# 2335000 entries processed
# 2338000 entries processed
# 2340000 entries processed
# 2342000 entries processed
# 2344000 entries processed
# 2345000 entries processed
# 2346000 entries processed
# 2347000 entries processed
# 2349000 entries processed
# 2350000 entries processed
# 2351000 entries processed
# 2352000 entries processed
# 2353000 entries processed
# 2355000 entries processed
# 2356000 entries processed
# 2358000 entries processed
# 2359000 entries processed
# 2363000 entries processed
# 2364000 entries processed
# 2366000 entries processed
# 2367000 entries processed
# 2368000 entries processed
# 2369000 entries processed
# 2370000 entries processed
# 2373000 entries processed
# 2377000 entries processed
# 2378000 entries processed
# 2379000 entries processed
# 2380000 entries processed
# 2382000 entries processed
# 2383000 entries processed
# 2384000 entries processed
# 2385000 entries processed
# 2387000 entries processed
# 2388000 entries processed
# 2389000 entries processed
# 2390000 entries processed
# 2391000 entries processed
# 2393000 entries processed
# 2395000 entries processed
# 2396000 entries processed
# 2397000 entries processed
# 2400000 entries processed
# 2402000 entries processed
# 2403000 entries processed
# 2404000 entries processed
# 2405000 entries processed
# 2409000 entries processed
# 2410000 entries processed
# 2411000 entries processed
# 2412000 entries processed
# 2414000 entries processed
# 2417000 entries processed
# 2418000 entries processed
# 2419000 entries processed
# 2420000 entries processed
# 2421000 entries processed
# 2425000 entries processed
# 2426000 entries processed
# 2427000 entries processed
# 2429000 entries processed
# 2430000 entries processed
# 2431000 entries processed
# 2434000 entries processed
# 2436000 entries processed
# 2439000 entries processed
# 2440000 entries processed
# 2442000 entries processed
# 2447000 entries processed
# 2448000 entries processed
# 2449000 entries processed
# 2452000 entries processed
# 2457000 entries processed
# 2459000 entries processed
# 2460000 entries processed
# 2461000 entries processed
# 2463000 entries processed
# 2464000 entries processed
# 2465000 entries processed
# 2467000 entries processed
# 2469000 entries processed
# 2471000 entries processed
# 2472000 entries processed
# 2474000 entries processed
# 2477000 entries processed
# 2478000 entries processed
# 2479000 entries processed
# 2480000 entries processed
# 2484000 entries processed
# 2485000 entries processed
# 2493000 entries processed
# 2494000 entries processed
# 2495000 entries processed
# 2498000 entries processed
# 2500000 entries processed
# 2502000 entries processed
# 2503000 entries processed
# 2505000 entries processed
# 2507000 entries processed
# 2508000 entries processed
# 2511000 entries processed
# 2512000 entries processed
# 2514000 entries processed
# 2519000 entries processed
# 2520000 entries processed
# 2521000 entries processed
# 2522000 entries processed
# 2523000 entries processed
# 2526000 entries processed
# 2528000 entries processed
# 2529000 entries processed
# 2530000 entries processed
# 2531000 entries processed
# 2533000 entries processed
# 2534000 entries processed
# 2535000 entries processed
# 2536000 entries processed
# 2537000 entries processed
# 2538000 entries processed
# 2543000 entries processed
# 2544000 entries processed
# 2546000 entries processed
# 2548000 entries processed
# 2549000 entries processed
# 2551000 entries processed
# 2552000 entries processed
# 2553000 entries processed
# 2556000 entries processed
# 2557000 entries processed
# 2558000 entries processed
# 2559000 entries processed
# 2562000 entries processed
# 2563000 entries processed
# 2565000 entries processed
# 2567000 entries processed
# 2568000 entries processed
# 2571000 entries processed
# 2572000 entries processed
# 2576000 entries processed
# 2578000 entries processed
# 2580000 entries processed
# 2590000 entries processed
# 2595000 entries processed
# 2596000 entries processed
# 2598000 entries processed
# 2601000 entries processed
# 2603000 entries processed
# 2604000 entries processed
# 2605000 entries processed
# 2606000 entries processed
# 2607000 entries processed
# 2610000 entries processed
# 2612000 entries processed
# 2613000 entries processed
# 2614000 entries processed
# 2619000 entries processed
# 2621000 entries processed
# 2623000 entries processed
# 2624000 entries processed
# 2625000 entries processed
# 2626000 entries processed
# 2628000 entries processed
# 2631000 entries processed
# 2632000 entries processed
# 2633000 entries processed
# 2637000 entries processed
# 2638000 entries processed
# 2647000 entries processed
# 2654000 entries processed
# 2656000 entries processed
# 2657000 entries processed
# 2658000 entries processed
# 2659000 entries processed
# 2664000 entries processed
# 2665000 entries processed
# 2666000 entries processed
# 2668000 entries processed
# 2669000 entries processed
# 2675000 entries processed
# 2678000 entries processed
# 2679000 entries processed
# 2681000 entries processed
# 2685000 entries processed
# 2687000 entries processed
# 2688000 entries processed
# 2692000 entries processed
# 2693000 entries processed
# 2694000 entries processed
# 2695000 entries processed
# 2696000 entries processed
# 2697000 entries processed
# 2698000 entries processed
# 2699000 entries processed
# 2702000 entries processed
# 2710000 entries processed
# 2711000 entries processed
# 2712000 entries processed
# 2716000 entries processed
# 2717000 entries processed
# 2719000 entries processed
# 2722000 entries processed
# 2724000 entries processed
# 2729000 entries processed
# 2730000 entries processed
# 2731000 entries processed
# 2732000 entries processed
# 2734000 entries processed
# 2735000 entries processed
# 2738000 entries processed
# 2739000 entries processed
# 2740000 entries processed
# 2741000 entries processed
# 2742000 entries processed
# 2743000 entries processed
# 2751000 entries processed
# 2757000 entries processed
# 2759000 entries processed
# 2760000 entries processed
# 2764000 entries processed
# 2765000 entries processed
# 2768000 entries processed
# 2771000 entries processed
# 2772000 entries processed
# 2775000 entries processed
# 2778000 entries processed
# 2779000 entries processed
# 2781000 entries processed
# 2784000 entries processed
# 2785000 entries processed
# 2786000 entries processed
# 2788000 entries processed
# 2791000 entries processed
# 2793000 entries processed
# 2794000 entries processed
# 2796000 entries processed
# 2799000 entries processed
# 2800000 entries processed
# 2801000 entries processed
# 2804000 entries processed
# 2805000 entries processed
# 2806000 entries processed
# 2807000 entries processed
# 2811000 entries processed
# 2816000 entries processed
# 2817000 entries processed
# 2821000 entries processed
# 2822000 entries processed
# 2823000 entries processed
# 2824000 entries processed
# 2826000 entries processed
# 2827000 entries processed
# 2830000 entries processed
# 2835000 entries processed
# 2836000 entries processed
# 2837000 entries processed
# 2838000 entries processed
# 2842000 entries processed
# 2843000 entries processed
# 2845000 entries processed
# 2848000 entries processed
# 2850000 entries processed
# 2855000 entries processed
# 2856000 entries processed
# 2858000 entries processed
# 2859000 entries processed
# 2860000 entries processed
# 2861000 entries processed
# 2863000 entries processed
# 2864000 entries processed
# 2866000 entries processed
# 2871000 entries processed
# 2872000 entries processed
# 2873000 entries processed
# 2875000 entries processed
# 2879000 entries processed
# 2882000 entries processed
# 2883000 entries processed
# 2884000 entries processed
# 2886000 entries processed
# 2889000 entries processed
# 2892000 entries processed
# WARNING! Could not find in-line type for relation http://dbpedia.org/ontology/suppreddedDate
# Found type in the next line. Check whether this is correct!
# 2893000 entries processed
# 2894000 entries processed
# 2899000 entries processed
# 2902000 entries processed
# 2905000 entries processed
# 2907000 entries processed
# 2908000 entries processed
# 2909000 entries processed
# 2912000 entries processed
# 2913000 entries processed
# 2917000 entries processed
# 2918000 entries processed
# 2919000 entries processed
# 2920000 entries processed
# 2921000 entries processed
# 2924000 entries processed
# 2925000 entries processed
# 2926000 entries processed
# 2927000 entries processed
# 2928000 entries processed
# 2931000 entries processed
# 2932000 entries processed
# 2933000 entries processed
# 2935000 entries processed
# 2936000 entries processed
# 2940000 entries processed
# 2944000 entries processed
# 2945000 entries processed
# 2946000 entries processed
# 2949000 entries processed
# 2952000 entries processed
# 2954000 entries processed
# 2956000 entries processed
# 2958000 entries processed
# 2962000 entries processed
# 2964000 entries processed
# 2967000 entries processed
# 2968000 entries processed
# 2969000 entries processed
# 2970000 entries processed
# 2972000 entries processed
# 2975000 entries processed
# 2978000 entries processed
# 2981000 entries processed
# 2982000 entries processed
# 2985000 entries processed
# 2987000 entries processed
# 2988000 entries processed
# 2989000 entries processed
# 2991000 entries processed
# 2994000 entries processed
# 2995000 entries processed
# 2996000 entries processed
# 3002000 entries processed
# 3004000 entries processed
# 3008000 entries processed
# 3009000 entries processed
# 3016000 entries processed
# 3019000 entries processed
# 3021000 entries processed
# 3022000 entries processed
# 3023000 entries processed
# 3024000 entries processed
# 3025000 entries processed
# 3026000 entries processed
# 3028000 entries processed
# 3030000 entries processed
# 3033000 entries processed
# 3035000 entries processed
# 3036000 entries processed
# 3041000 entries processed
# 3042000 entries processed
# 3048000 entries processed
# 3051000 entries processed
# 3054000 entries processed
# 3055000 entries processed
# 3057000 entries processed
# 3059000 entries processed
# 3060000 entries processed
# 3064000 entries processed
# 3066000 entries processed
# 3072000 entries processed
# 3073000 entries processed
# 3075000 entries processed
# 3078000 entries processed
# 3082000 entries processed
# 3083000 entries processed
# 3086000 entries processed
# 3089000 entries processed
# 3093000 entries processed
# 3096000 entries processed
# 3098000 entries processed
# 3100000 entries processed
# 3101000 entries processed
# 3102000 entries processed
# 3109000 entries processed
# 3111000 entries processed
# 3114000 entries processed
# 3116000 entries processed
# 3117000 entries processed
# 3119000 entries processed
# 3123000 entries processed
# 3125000 entries processed
# 3129000 entries processed
# 3131000 entries processed
# 3132000 entries processed
# 3133000 entries processed
# 3134000 entries processed
# 3136000 entries processed
# 3138000 entries processed
# 3139000 entries processed
# 3140000 entries processed
# 3145000 entries processed
# 3147000 entries processed
# 3148000 entries processed
# 3151000 entries processed
# 3158000 entries processed
# 3159000 entries processed
# 3161000 entries processed
# 3162000 entries processed
# 3165000 entries processed
# 3168000 entries processed
# 3169000 entries processed
# 3170000 entries processed
# 3171000 entries processed
# 3172000 entries processed
# 3173000 entries processed
# 3174000 entries processed
# 3176000 entries processed
# 3177000 entries processed
# 3178000 entries processed
# 3179000 entries processed
# 3180000 entries processed
# 3183000 entries processed
# 3184000 entries processed
# 3186000 entries processed
# 3187000 entries processed
# 3188000 entries processed
# 3189000 entries processed
# 3190000 entries processed
# 3191000 entries processed
# 3194000 entries processed
# 3196000 entries processed
# 3197000 entries processed
# 3199000 entries processed
# 3200000 entries processed
# 3201000 entries processed
# 3202000 entries processed
# 3204000 entries processed
# 3205000 entries processed
# 3207000 entries processed
# 3210000 entries processed
# 3211000 entries processed
# 3212000 entries processed
# 3213000 entries processed
# 3216000 entries processed
# 3217000 entries processed
# 3218000 entries processed
# 3219000 entries processed
# 3220000 entries processed
# 3221000 entries processed
# 3222000 entries processed
# 3223000 entries processed
# 3224000 entries processed
# 3225000 entries processed
# 3227000 entries processed
# 3228000 entries processed
# 3229000 entries processed
# 3230000 entries processed
# 3231000 entries processed
# 3232000 entries processed
# 3233000 entries processed
# 3234000 entries processed
# 3235000 entries processed
# 3237000 entries processed
# 3239000 entries processed
# 3241000 entries processed
# 3242000 entries processed
# 3244000 entries processed
# 3250000 entries processed
# 3251000 entries processed
# 3253000 entries processed
# 3255000 entries processed
# 3256000 entries processed
# 3257000 entries processed
# 3258000 entries processed
# 3259000 entries processed
# 3266000 entries processed
# 3268000 entries processed
# 3270000 entries processed
# 3272000 entries processed
# 3274000 entries processed
# 3275000 entries processed
# 3280000 entries processed
# 3281000 entries processed
# 3283000 entries processed
# 3285000 entries processed
# 3286000 entries processed
# 3288000 entries processed
# 3289000 entries processed
# 3291000 entries processed
# 3292000 entries processed
# 3293000 entries processed
# 3295000 entries processed
# 3297000 entries processed
# 3298000 entries processed
# 3302000 entries processed
# 3303000 entries processed
# 3305000 entries processed
# 3307000 entries processed
# 3309000 entries processed
# 3313000 entries processed
# 3315000 entries processed
# 3318000 entries processed
# 3320000 entries processed
# 3322000 entries processed
# 3323000 entries processed
# 3325000 entries processed
# 3326000 entries processed
# 3328000 entries processed
# 3329000 entries processed
# 3331000 entries processed
# 3332000 entries processed
# 3333000 entries processed
# 3336000 entries processed
# 3339000 entries processed
# 3340000 entries processed
# 3341000 entries processed
# 3343000 entries processed
# 3345000 entries processed
# 3348000 entries processed
# 3349000 entries processed
# 3350000 entries processed
# 3353000 entries processed
# 3357000 entries processed
# 3358000 entries processed
# 3360000 entries processed
# 3362000 entries processed
# 3363000 entries processed
# 3364000 entries processed
# 3365000 entries processed
# 3366000 entries processed
# 3367000 entries processed
# 3370000 entries processed
# 3371000 entries processed
# 3379000 entries processed
# 3381000 entries processed
# 3382000 entries processed
# 3383000 entries processed
# 3385000 entries processed
# 3387000 entries processed
# 3390000 entries processed
# 3391000 entries processed
# 3392000 entries processed
# 3393000 entries processed
# 3394000 entries processed
# 3395000 entries processed
# 3396000 entries processed
# 3399000 entries processed
# 3400000 entries processed
# 3401000 entries processed
# 3404000 entries processed
# 3406000 entries processed
# 3414000 entries processed
# 3416000 entries processed
# 3419000 entries processed
# 3422000 entries processed
# 3424000 entries processed
# 3428000 entries processed
# 3429000 entries processed
# 3430000 entries processed
# 3431000 entries processed
# 3432000 entries processed
# 3434000 entries processed
# 3435000 entries processed
# 3438000 entries processed
# 3441000 entries processed
# 3445000 entries processed
# 3447000 entries processed
# 3449000 entries processed
# 3452000 entries processed
# 3453000 entries processed
# 3455000 entries processed
# 3464000 entries processed
# 3466000 entries processed
# 3468000 entries processed
# 3470000 entries processed
# 3471000 entries processed
# 3474000 entries processed
# 3476000 entries processed
# 3479000 entries processed
# 3480000 entries processed
# 3481000 entries processed
# 3482000 entries processed
# 3489000 entries processed
# 3490000 entries processed
# 3491000 entries processed
# 3492000 entries processed
# 3497000 entries processed
# 3500000 entries processed
# 3501000 entries processed
# 3502000 entries processed
# 3504000 entries processed
# 3506000 entries processed
# 3508000 entries processed
# 3509000 entries processed
# 3511000 entries processed
# 3513000 entries processed
# 3518000 entries processed
# 3519000 entries processed
# 3520000 entries processed
# 3521000 entries processed
# 3522000 entries processed
# 3524000 entries processed
# 3525000 entries processed
# 3526000 entries processed
# 3527000 entries processed
# 3528000 entries processed
# 3530000 entries processed
# 3532000 entries processed
# 3535000 entries processed
# 3536000 entries processed
# 3540000 entries processed
# 3542000 entries processed
# 3544000 entries processed
# 3546000 entries processed
# 3547000 entries processed
# 3548000 entries processed
# 3549000 entries processed
# 3550000 entries processed
# 3551000 entries processed
# 3552000 entries processed
# 3557000 entries processed
# 3561000 entries processed
# 3562000 entries processed
# ...
# 13236000 entries processed
# 13237000 entries processed
# 13238000 entries processed
# 13244000 entries processed
# 13249000 entries processed
# 13250000 entries processed
# 13251000 entries processed
# 13252000 entries processed
# 13253000 entries processed
# 13254000 entries processed
# 13255000 entries processed
# 13258000 entries processed
# 13259000 entries processed
# 13265000 entries processed
# 13266000 entries processed
# 13267000 entries processed
# 13269000 entries processed
# 13270000 entries processed
# 13271000 entries processed
# 13272000 entries processed
# 13273000 entries processed
# 13274000 entries processed
# 13275000 entries processed
# 13276000 entries processed
# 13280000 entries processed
# 13281000 entries processed
# 13282000 entries processed
# 13283000 entries processed
# 13284000 entries processed
# 13287000 entries processed
# 13288000 entries processed
# 13290000 entries processed
# 13291000 entries processed
# 13292000 entries processed
# 13296000 entries processed
# 13297000 entries processed
# 13300000 entries processed
# 13301000 entries processed
# 13304000 entries processed
# 13306000 entries processed
# 13307000 entries processed
# 13308000 entries processed
# 13310000 entries processed
# 13312000 entries processed
# 13314000 entries processed
# 13315000 entries processed
# 13317000 entries processed
# 13321000 entries processed
# 13322000 entries processed
# 13323000 entries processed
# 13325000 entries processed
# 13326000 entries processed
# 13328000 entries processed
# 13329000 entries processed
# 13330000 entries processed
# 13331000 entries processed
# 13333000 entries processed
# 13338000 entries processed
# 13342000 entries processed
# 13343000 entries processed
# 13345000 entries processed
# 13346000 entries processed
# 13347000 entries processed
# 13348000 entries processed
# 13353000 entries processed
# 13358000 entries processed
# 13359000 entries processed
# 13362000 entries processed
# 13367000 entries processed
# 13369000 entries processed
# 13370000 entries processed
# 13371000 entries processed
# 13372000 entries processed
# 13373000 entries processed
# 13374000 entries processed
# 13375000 entries processed
# 13381000 entries processed
# 13382000 entries processed
# 13384000 entries processed
# 13385000 entries processed
# 13387000 entries processed
# 13390000 entries processed
# 13392000 entries processed
# 13395000 entries processed
# 13397000 entries processed
# 13398000 entries processed
# 13399000 entries processed
# 13400000 entries processed
# 13401000 entries processed
# 13402000 entries processed
# 13404000 entries processed
# 13406000 entries processed
# 13408000 entries processed
# 13411000 entries processed
# 13416000 entries processed
# 13420000 entries processed
# 13421000 entries processed
# 13422000 entries processed
# 13424000 entries processed
# 13425000 entries processed
# 13426000 entries processed
# 13427000 entries processed
# 13429000 entries processed
# 13431000 entries processed
# 13433000 entries processed
# 13434000 entries processed
# 13436000 entries processed
# 13437000 entries processed
# 13438000 entries processed
# 13440000 entries processed
# 13441000 entries processed
# 13442000 entries processed
# 13443000 entries processed
# 13446000 entries processed
# 13447000 entries processed
# 13448000 entries processed
# 13449000 entries processed
# 13450000 entries processed
# 13451000 entries processed
# 13454000 entries processed
# 13459000 entries processed
# 13461000 entries processed
# 13462000 entries processed
# 13466000 entries processed
# 13467000 entries processed
# 13468000 entries processed
# 13471000 entries processed
# 13479000 entries processed
# 13480000 entries processed
# 13481000 entries processed
# 13483000 entries processed
# 13484000 entries processed
# 13486000 entries processed
# 13488000 entries processed
# 13491000 entries processed
# 13493000 entries processed
# 13494000 entries processed
# 13500000 entries processed
# 13501000 entries processed
# 13503000 entries processed
# 13505000 entries processed
# 13507000 entries processed
# 13508000 entries processed
# 13509000 entries processed
# 13511000 entries processed
# 13513000 entries processed
# 13514000 entries processed
# 13515000 entries processed
# 13517000 entries processed
# 13518000 entries processed
# 13522000 entries processed
# 13523000 entries processed
# 13528000 entries processed
# 13532000 entries processed
# 13533000 entries processed
# 13534000 entries processed
# 13537000 entries processed
# 13540000 entries processed
# 13542000 entries processed
# 13543000 entries processed
# 13546000 entries processed
# 13547000 entries processed
# 13550000 entries processed
# 13551000 entries processed
# 13554000 entries processed
# 13555000 entries processed
# 13556000 entries processed
# 13557000 entries processed
# 13559000 entries processed
# 13563000 entries processed
# 13564000 entries processed
# 13565000 entries processed
# 13566000 entries processed
# 13567000 entries processed
# 13568000 entries processed
# 13569000 entries processed
# 13570000 entries processed
# 13571000 entries processed
# 13572000 entries processed
# 13573000 entries processed
# 13577000 entries processed
# 13583000 entries processed
# 13585000 entries processed
# 13586000 entries processed
# 13587000 entries processed
# 13590000 entries processed
# 13591000 entries processed
# 13594000 entries processed
# 13596000 entries processed
# 13597000 entries processed
# 13599000 entries processed
# 13600000 entries processed
# 13601000 entries processed
# 13603000 entries processed
# 13605000 entries processed
# 13608000 entries processed
# 13613000 entries processed
# 13616000 entries processed
# 13618000 entries processed
# 13619000 entries processed
# 13621000 entries processed
# 13623000 entries processed
# 13626000 entries processed
# 13627000 entries processed
# 13628000 entries processed
# 13630000 entries processed
# 13631000 entries processed
# 13632000 entries processed
# 13633000 entries processed
# 13636000 entries processed
# 13637000 entries processed
# 13640000 entries processed
# 13641000 entries processed
# 13643000 entries processed
# 13646000 entries processed
# 13647000 entries processed
# 13651000 entries processed
# 13655000 entries processed
# 13656000 entries processed
# 13658000 entries processed
# 13659000 entries processed
# 13661000 entries processed
# 13662000 entries processed
# 13663000 entries processed
# 13668000 entries processed
# 13670000 entries processed
# 13671000 entries processed
# 13674000 entries processed
# 13677000 entries processed
# 13680000 entries processed
# 13682000 entries processed
# 13685000 entries processed
# 13686000 entries processed
# 13688000 entries processed
# 13691000 entries processed
# 13693000 entries processed
# 13694000 entries processed
# 13696000 entries processed
# 13700000 entries processed
# 13702000 entries processed
# 13704000 entries processed
# 13705000 entries processed
# 13706000 entries processed
# 13707000 entries processed
# 13711000 entries processed
# 13712000 entries processed
# 13713000 entries processed
# 13718000 entries processed
# 13721000 entries processed
# 13722000 entries processed
# 13723000 entries processed
# 13726000 entries processed
# 13727000 entries processed
# 13728000 entries processed
# 13733000 entries processed
# 13734000 entries processed
# 13735000 entries processed
# 13738000 entries processed
# 13745000 entries processed
# 13747000 entries processed
# 13749000 entries processed
# 13750000 entries processed
# 13753000 entries processed
# 13754000 entries processed
# 13756000 entries processed
# 13757000 entries processed
# 13758000 entries processed
# 13762000 entries processed
# 13763000 entries processed
# 13764000 entries processed
# 13765000 entries processed
# 13767000 entries processed
# 13768000 entries processed
# 13771000 entries processed
# 13774000 entries processed
# 13775000 entries processed
# 13776000 entries processed
# 13781000 entries processed
# 13782000 entries processed
# 13784000 entries processed
# 13785000 entries processed
# 13786000 entries processed
# 13787000 entries processed
# 13788000 entries processed
# 13789000 entries processed
# 13795000 entries processed
# 13803000 entries processed
# 13805000 entries processed
# 13806000 entries processed
# 13807000 entries processed
# 13808000 entries processed
# 13809000 entries processed
# 13810000 entries processed
# 13813000 entries processed
# 13814000 entries processed
# 13815000 entries processed
# 13816000 entries processed
# 13818000 entries processed
# 13821000 entries processed
# 13827000 entries processed
# 13828000 entries processed
# 13830000 entries processed
# 13831000 entries processed
# 13832000 entries processed
# 13833000 entries processed
# 13836000 entries processed
# 13838000 entries processed
# 13839000 entries processed
# 13841000 entries processed
# 13846000 entries processed
# 13847000 entries processed
# 13848000 entries processed
# 13849000 entries processed
# 13850000 entries processed
# 13852000 entries processed
# 13854000 entries processed
# 13855000 entries processed
# 13857000 entries processed
# 13858000 entries processed
# 13860000 entries processed
# 13861000 entries processed
# 13864000 entries processed
# 13866000 entries processed
# 13871000 entries processed
# 13872000 entries processed
# 13878000 entries processed
# 13879000 entries processed
# 13880000 entries processed
# 13881000 entries processed
# 13882000 entries processed
# 13884000 entries processed
# 13885000 entries processed
# 13886000 entries processed
# 13888000 entries processed
# 13892000 entries processed
# 13894000 entries processed
# 13896000 entries processed
# 13898000 entries processed
# 13900000 entries processed
# 13902000 entries processed
# 13906000 entries processed
# 13908000 entries processed
# 13914000 entries processed
# 13915000 entries processed
# 13920000 entries processed
# 13921000 entries processed
# 13922000 entries processed
# 13923000 entries processed
# 13925000 entries processed
# 13926000 entries processed
# 13927000 entries processed
# 13930000 entries processed
# 13934000 entries processed
# 13936000 entries processed
# 13938000 entries processed
# 13939000 entries processed
# 13943000 entries processed
# 13945000 entries processed
# 13946000 entries processed
# 13947000 entries processed
# 13955000 entries processed
# 13959000 entries processed
# 13961000 entries processed
# 13963000 entries processed
# 13964000 entries processed
# 13965000 entries processed
# 13966000 entries processed
# 13967000 entries processed
# 13968000 entries processed
# 13969000 entries processed
# 13970000 entries processed
# 13973000 entries processed
# 13975000 entries processed
# 13978000 entries processed
# 13980000 entries processed
# 13981000 entries processed
# 13983000 entries processed
# 13990000 entries processed
# 13994000 entries processed
# 13996000 entries processed
# 13997000 entries processed
# 13999000 entries processed
# 14000000 entries processed
# 14001000 entries processed
# 14002000 entries processed
# 14004000 entries processed
# 14006000 entries processed
# 14008000 entries processed
# 14009000 entries processed
# 14011000 entries processed
# 14012000 entries processed
# 14013000 entries processed
# 14015000 entries processed
# 14017000 entries processed
# 14020000 entries processed
# 14022000 entries processed
# 14024000 entries processed
# 14025000 entries processed
# 14026000 entries processed
# 14027000 entries processed
# 14028000 entries processed
# 14032000 entries processed
# 14035000 entries processed
# 14037000 entries processed
# 14038000 entries processed
# 14039000 entries processed
# 14040000 entries processed
# 14045000 entries processed
# 14048000 entries processed
# 14049000 entries processed
# 14051000 entries processed
# 14054000 entries processed
# 14055000 entries processed
# 14057000 entries processed
# 14066000 entries processed
# 14068000 entries processed
# 14069000 entries processed
# 14070000 entries processed
# 14071000 entries processed
# 14074000 entries processed
# 14075000 entries processed
# 14076000 entries processed
# 14077000 entries processed
# 14078000 entries processed
# 14079000 entries processed
# 14084000 entries processed
# 14085000 entries processed
# 14086000 entries processed
# 14087000 entries processed
# 14088000 entries processed
# 14090000 entries processed
# 14091000 entries processed
# 14092000 entries processed
# 14094000 entries processed
# 14095000 entries processed
# 14096000 entries processed
# 14097000 entries processed
# 14100000 entries processed
# 14102000 entries processed
# 14104000 entries processed
# 14106000 entries processed
# 14108000 entries processed
# 14113000 entries processed
# 14114000 entries processed
# 14117000 entries processed
# 14118000 entries processed
# 14123000 entries processed
# 14124000 entries processed
# 14125000 entries processed
# 14126000 entries processed
# 14131000 entries processed
# 14132000 entries processed
# 14133000 entries processed
# 14134000 entries processed
# 14138000 entries processed
# 14140000 entries processed
# 14141000 entries processed
# 14145000 entries processed
# 14147000 entries processed
# 14149000 entries processed
# 14150000 entries processed
# 14151000 entries processed
# 14153000 entries processed
# 14154000 entries processed
# 14156000 entries processed
# 14158000 entries processed
# 14160000 entries processed
# 14162000 entries processed
# 14163000 entries processed
# 14165000 entries processed
# 14167000 entries processed
# 14170000 entries processed
# 14172000 entries processed
# 14174000 entries processed
# 14175000 entries processed
# 14176000 entries processed
# 14177000 entries processed
# 14179000 entries processed
# 14180000 entries processed
# 14181000 entries processed
# 14182000 entries processed
# 14184000 entries processed
# 14186000 entries processed
# 14187000 entries processed
# 14190000 entries processed
# 14191000 entries processed
# 14193000 entries processed
# 14194000 entries processed
# 14195000 entries processed
# 14198000 entries processed
# 14199000 entries processed
# 14200000 entries processed
# 14203000 entries processed
# 14205000 entries processed
# 14206000 entries processed
# 14211000 entries processed
# 14213000 entries processed
# 14214000 entries processed
# 14216000 entries processed
# 14218000 entries processed
# 14219000 entries processed
# 14220000 entries processed
# 14221000 entries processed
# 14223000 entries processed
# 14226000 entries processed
# 14236000 entries processed
# 14237000 entries processed
# 14239000 entries processed
# 14240000 entries processed
# 14242000 entries processed
# 14243000 entries processed
# 14245000 entries processed
# 14248000 entries processed
# 14255000 entries processed
# 14258000 entries processed
# 14259000 entries processed
# 14261000 entries processed
# 14262000 entries processed
# 14264000 entries processed
# 14265000 entries processed
# 14267000 entries processed
# 14269000 entries processed
# 14270000 entries processed
# 14272000 entries processed
# 14273000 entries processed
# 14274000 entries processed
# 14276000 entries processed
# 14278000 entries processed
# 14279000 entries processed
# 14280000 entries processed
# 14281000 entries processed
# 14282000 entries processed
# 14283000 entries processed
# 14284000 entries processed
# 14286000 entries processed
# 14287000 entries processed
# 14289000 entries processed
# 14291000 entries processed
# 14294000 entries processed
# 14295000 entries processed
# 14298000 entries processed
# 14302000 entries processed
# 14303000 entries processed
# 14306000 entries processed
# 14308000 entries processed
# 14312000 entries processed
# 14314000 entries processed
# 14315000 entries processed
# 14316000 entries processed
# 14317000 entries processed
# 14318000 entries processed
# 14319000 entries processed
# 14320000 entries processed
# 14323000 entries processed
# 14324000 entries processed
# 14328000 entries processed
# 14329000 entries processed
# 14333000 entries processed
# 14334000 entries processed
# 14337000 entries processed
# 14338000 entries processed
# 14340000 entries processed
# 14344000 entries processed
# 14345000 entries processed
# 14347000 entries processed
# 14348000 entries processed
# 14349000 entries processed
# 14356000 entries processed
# 14357000 entries processed
# 14359000 entries processed
# 14363000 entries processed
# 14364000 entries processed
# 14365000 entries processed
# 14367000 entries processed
# 14368000 entries processed
# 14369000 entries processed
# 14373000 entries processed
# 14375000 entries processed
# 14376000 entries processed
# 14377000 entries processed
# 14379000 entries processed
# 14380000 entries processed
# 14382000 entries processed
# 14383000 entries processed
# 14384000 entries processed
# 14385000 entries processed
# 14386000 entries processed
# WARNING! Could not find in-line type for relation http://dbpedia.org/ontology/rkdArtistsId
# Found type in the next line. Check whether this is correct!

# %%
relation_type_dict
# Out:
# {'http://dbpedia.org/ontology/aSide': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/abbreviation': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/absoluteMagnitude': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/acceleration': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/access': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/acquirementDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/activeYears': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/activeYearsEndDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/activeYearsEndYear': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/activeYearsStartDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/activeYearsStartYear': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/added': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/address': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString',
#  'http://dbpedia.org/ontology/ageRange': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/agencyStationCode': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/albedo': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/alias': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString',
#  'http://dbpedia.org/ontology/allegiance': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/alternativeName': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString',
#  'http://dbpedia.org/ontology/analogChannel': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/anniversary': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/apoapsis': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/apparentMagnitude': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/approximateCalories': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/area': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/areaCode': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/areaLand': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/areaMetro': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/areaOfCatchment': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/areaOfCatchmentQuote': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/areaQuote': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/areaRural': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/areaTotal': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/areaUrban': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/areaWater': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/argueDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/arm': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/assetUnderManagement': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/assets': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/atcPrefix': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/atcSuffix': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/atcSupplemental': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/automobileModel': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/averageAnnualGeneration': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/averageClassSize': 'http://www.w3.org/2001/XMLSchema#float',
#  'http://dbpedia.org/ontology/averageDepth': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/averageDepthQuote': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/averageSpeed': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/bSide': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/background': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/band': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/barPassRate': 'http://www.w3.org/2001/XMLSchema#float',
#  'http://dbpedia.org/ontology/battingSide': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/battleHonours': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/beatifiedDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/bedCount': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/bestFinish': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/bibsysId': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/bicycleInformation': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/bioavailability': 'http://www.w3.org/2001/XMLSchema#float',
#  'http://dbpedia.org/ontology/birthDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/birthName': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString',
#  'http://dbpedia.org/ontology/birthYear': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/block': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/bnfId': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/bowlRecord': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/bpnId': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/brainInfoNumber': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/brainInfoType': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/bridgeCarries': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/broadcastRepeater': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/broadcastStationClass': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/broadcastTranslator': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/budget': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/buildingEndDate': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/buildingEndYear': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/buildingStartDate': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/buildingStartYear': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/bustSize': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/callSign': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/callsignMeaning': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/campusSize': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/campusType': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString',
#  'http://dbpedia.org/ontology/canBaggageChecked': 'http://www.w3.org/2001/XMLSchema#boolean',
#  'http://dbpedia.org/ontology/canonizedDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/capacity': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/capacityFactor': 'http://www.w3.org/2001/XMLSchema#float',
#  'http://dbpedia.org/ontology/capitalElevation': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/captureDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/carNumber': 'http://www.w3.org/2001/XMLSchema#integer',
#  'http://dbpedia.org/ontology/carbohydrate': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/careerPrizeMoney': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/casNumber': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/casSupplemental': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/casualties': 'http://www.w3.org/2001/XMLSchema#integer',
#  'http://dbpedia.org/ontology/causalties': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/ceeb': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/censusYear': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/centuryBreaks': 'http://www.w3.org/2001/XMLSchema#integer',
#  'http://dbpedia.org/ontology/certification': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/certificationDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/chEBI': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/chairmanTitle': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString',
#  'http://dbpedia.org/ontology/championships': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/characterInPlay': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/chorusCharacterInPlay': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/christeningDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/chromosome': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/circulation': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/cityType': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/classes': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/closed': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/closingDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/closingYear': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/cmykCoordinateBlack': 'http://www.w3.org/2001/XMLSchema#integer',
#  'http://dbpedia.org/ontology/cmykCoordinateCyanic': 'http://www.w3.org/2001/XMLSchema#integer',
#  'http://dbpedia.org/ontology/cmykCoordinateMagenta': 'http://www.w3.org/2001/XMLSchema#integer',
#  'http://dbpedia.org/ontology/cmykCoordinateYellow': 'http://www.w3.org/2001/XMLSchema#integer',
#  'http://dbpedia.org/ontology/co2Emission': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/coachingRecord': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/code': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/coden': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/collection': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/colourHexCode': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/colourName': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString',
#  'http://dbpedia.org/ontology/combatant': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/commissioningDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/committee': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/commonName': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString',
#  'http://dbpedia.org/ontology/completionDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/complexity': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/compressionRatio': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/configuration': 'http://dbpedia.org/datatype/engineConfiguration',
#  'http://dbpedia.org/ontology/conservationStatus': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/conservationStatusSystem': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/contractAward': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/cosparId': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/cost': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/course': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/crews': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/crownDependency': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/cuisine': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/currentRank': 'http://www.w3.org/2001/XMLSchema#integer',
#  'http://dbpedia.org/ontology/currentRecord': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/currentSeason': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/currentStatus': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/currentlyUsedFor': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/cylinderBore': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/cylinderCount': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/date': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/dateAct': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/dateCompleted': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/dateConstruction': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/dateOfAbandonment': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/dateOfBurial': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/dateUse': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/day': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/dcc': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/deathDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/deathYear': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/debut': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/decideDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/declination': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/decommissioningDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/deliveryDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/demolitionDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/demolitionYear': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/demonym': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString',
#  'http://dbpedia.org/ontology/density': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/depictionDescription': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString',
#  'http://dbpedia.org/ontology/depth': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/description': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString',
#  'http://dbpedia.org/ontology/destructionDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/detectionMethod': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/diameter': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/digitalChannel': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/digitalSubChannel': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/disbanded': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/discharge': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/dischargeAverage': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/discovered': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/displacement': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/dissolutionDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/dissolutionYear': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/dissolved': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/distance': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/distanceLaps': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/distanceToBelfast': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/distanceToCardiff': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/distanceToCharingCross': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/distanceToDouglas': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/distanceToDublin': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/distanceToEdinburgh': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/distanceToLondon': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/dorlandsPrefix': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/dorlandsSuffix': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/draft': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/draftPick': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/draftRound': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/draftYear': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/dressCode': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/drugbank': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/duration': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/ecNumber': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/editorTitle': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString',
#  'http://dbpedia.org/ontology/effectiveRadiatedPower': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/electionDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/electionDateLeader': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/electionMajority': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/elevation': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/elevationQuote': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/endDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/endYearOfInsertion': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/endYearOfSales': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/endowment': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/ensembl': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/entrezgene': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/episodeNumber': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/epoch': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/equity': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/eruptionYear': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/escapeVelocity': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/espnId': 'http://www.w3.org/2001/XMLSchema#integer',
#  'http://dbpedia.org/ontology/established': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/ethnicGroupsInYear': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/extinctionDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/extinctionYear': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/eyeColor': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/faaLocationIdentifier': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/facilityId': 'http://www.w3.org/2001/XMLSchema#integer',
#  'http://dbpedia.org/ontology/facultySize': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/failedLaunches': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/fansgroup': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/fareZone': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/fastestLap': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/fat': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/fate': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString',
#  'http://dbpedia.org/ontology/fdaUniiCode': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/feastDay': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/fees': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/fileSize': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/filename': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/finalFlight': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/finalPublicationYear': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/firstAirDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/firstAppearance': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/firstAscentYear': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/firstFlightEndDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/firstFlightStartDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/firstGame': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/firstLaunchDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/firstPublicationDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/firstPublicationYear': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/flag': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/floodingDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/floorArea': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/floorCount': 'http://www.w3.org/2001/XMLSchema#positiveInteger',
#  'http://dbpedia.org/ontology/foalDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/formationDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/formationYear': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/formerCallsign': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/formerChannel': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/formerName': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString',
#  'http://dbpedia.org/ontology/foundingDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/foundingYear': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/frequency': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/frequencyOfPublication': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/frequentlyUpdated': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/frozen': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/fuelCapacity': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/fuelConsumption': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/fuelType': 'http://dbpedia.org/datatype/fuelType',
#  'http://dbpedia.org/ontology/games': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/gasChambers': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/geneLocationEnd': 'http://www.w3.org/2001/XMLSchema#integer',
#  'http://dbpedia.org/ontology/geneLocationStart': 'http://www.w3.org/2001/XMLSchema#integer',
#  'http://dbpedia.org/ontology/generationUnits': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString',
#  'http://dbpedia.org/ontology/genomeDB': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/geologicPeriod': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/geology': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/glycemicIndex': 'http://www.w3.org/2001/XMLSchema#integer',
#  'http://dbpedia.org/ontology/governmentElevation': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/grayPage': 'http://www.w3.org/2001/XMLSchema#positiveInteger',
#  'http://dbpedia.org/ontology/graySubject': 'http://www.w3.org/2001/XMLSchema#positiveInteger',
#  'http://dbpedia.org/ontology/gridReference': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/gross': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/grossDomesticProduct': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/hairColor': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/hallOfFame': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/headLabel': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString',
#  'http://dbpedia.org/ontology/height': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/heightAboveAverageTerrain': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/hgncid': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/highestBreak': 'http://www.w3.org/2001/XMLSchema#integer',
#  'http://dbpedia.org/ontology/highestRank': 'http://www.w3.org/2001/XMLSchema#integer',
#  'http://dbpedia.org/ontology/hipSize': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/hsvCoordinateHue': 'http://www.w3.org/2001/XMLSchema#integer',
#  'http://dbpedia.org/ontology/hsvCoordinateSaturation': 'http://www.w3.org/2001/XMLSchema#integer',
#  'http://dbpedia.org/ontology/hsvCoordinateValue': 'http://www.w3.org/2001/XMLSchema#integer',
#  'http://dbpedia.org/ontology/iataAirlineCode': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/iataLocationIdentifier': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/ibdbId': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/icaoAirlineCode': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/icaoLocationIdentifier': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/icd10': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/icd9': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/icdo': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/id': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/identificationSymbol': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/imageSize': 'http://www.w3.org/2001/XMLSchema#integer',
#  'http://dbpedia.org/ontology/imdbId': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/impactFactor': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/impactFactorAsOf': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/individualisedGnd': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/ingredientName': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/inseeCode': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/installedCapacity': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/interest': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/internationally': 'http://www.w3.org/2001/XMLSchema#boolean',
#  'http://dbpedia.org/ontology/introduced': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/introductionDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/isHandicappedAccessible': 'http://www.w3.org/2001/XMLSchema#boolean',
#  'http://dbpedia.org/ontology/isPartOfName': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/isPeerReviewed': 'http://www.w3.org/2001/XMLSchema#boolean',
#  'http://dbpedia.org/ontology/isbn': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/isniId': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/iso6391Code': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/iso6392Code': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/iso6393Code': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/isoCodeRegion': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/issDockings': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/issn': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/iucnCategory': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/iupacName': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString',
#  'http://dbpedia.org/ontology/jstor': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/largestWin': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/lastAirDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/lastElectionDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/lastFlightEndDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/lastFlightStartDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/lastLaunchDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/lastPosition': 'http://www.w3.org/2001/XMLSchema#positiveInteger',
#  'http://dbpedia.org/ontology/lastPublicationDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/latestPreviewDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/latestPreviewVersion': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/latestReleaseDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/latestReleaseVersion': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/launches': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/layingDown': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/lcc': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/lccn': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/lccnId': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/leaderTitle': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString',
#  'http://dbpedia.org/ontology/legislativePeriodName': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/length': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/lengthQuote': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/lengthReference': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/liberationDate': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/licensee': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/lineLength': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/loadLimit': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/locationIdentifier': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/locusSupplementaryData': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/logo': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/longName': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString',
#  'http://dbpedia.org/ontology/longtype': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/lowerAge': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/lowerEarthOrbitPayload': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/lowest': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/maidenFlight': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/maidenVoyage': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/mainspan': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/managementElevation': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/managerTitle': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/mapCaption': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/mascot': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/mass': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/material': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/maxTime': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/maximumBoatBeam': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/maximumBoatLength': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/maximumDepth': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/maximumDepthQuote': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/maximumDischarge': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/maximumElevation': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/maximumTemperature': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/mbaId': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/meanRadius': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/meanTemperature': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/meaning': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/membership': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString',
#  'http://dbpedia.org/ontology/meshId': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/meshName': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString',
#  'http://dbpedia.org/ontology/meshNumber': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/mgiid': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/militaryCommand': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/militaryUnitSize': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/minTime': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/minimumDischarge': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/minimumElevation': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/minimumTemperature': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/mirDockings': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/missions': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/model': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/modelEndYear': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/modelStartYear': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/month': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/motto': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/mouthElevation': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/municipalityCode': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/muteCharacterInPlay': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/name': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString',
#  'http://dbpedia.org/ontology/nameDay': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/nationalRanking': 'http://www.w3.org/2001/XMLSchema#positiveInteger',
#  'http://dbpedia.org/ontology/nationalTopographicSystemMapNumber': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/ndlId': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/neighbourConstellations': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/netIncome': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/networth': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/nlaId': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/note': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/notes': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/nrhpReferenceNumber': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/nssdcId': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/number': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/numberBuilt': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfBronzeMedalsWon': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfCompetitors': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfDeaths': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/numberOfDoctoralStudents': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfEmployees': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfEpisodes': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfFilms': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfGoals': 'http://www.w3.org/2001/XMLSchema#integer',
#  'http://dbpedia.org/ontology/numberOfGoldMedalsWon': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfGraduateStudents': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfIslands': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfLanes': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfLawyers': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfLines': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfLocations': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfMatches': 'http://www.w3.org/2001/XMLSchema#integer',
#  'http://dbpedia.org/ontology/numberOfMembers': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfOffices': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfOfficials': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfPads': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfPages': 'http://www.w3.org/2001/XMLSchema#positiveInteger',
#  'http://dbpedia.org/ontology/numberOfParkingSpaces': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfParticipatingAthletes': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfParticipatingNations': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfPiersInWater': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfPlatformLevels': 'http://www.w3.org/2001/XMLSchema#integer',
#  'http://dbpedia.org/ontology/numberOfPostgraduateStudents': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfRestaurants': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfRooms': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfSeasons': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfSilverMedalsWon': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfSpans': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfSports': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfStaff': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfStations': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfStudents': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfSuites': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfTeams': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfTracks': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfUndergraduateStudents': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfVehicles': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfVineyards': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfVisitors': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfVisitorsAsOf': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/numberOfVolumes': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfVolunteers': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberOfWineries': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/numberSold': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/nutsCode': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/oclc': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/offeredClasses': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/office': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/officialSchoolColour': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/oldcode': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/omim': 'http://www.w3.org/2001/XMLSchema#integer',
#  'http://dbpedia.org/ontology/onChromosome': 'http://www.w3.org/2001/XMLSchema#integer',
#  'http://dbpedia.org/ontology/openAccessContent': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/openingDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/openingYear': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/operatingIncome': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/orbitalFlights': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/orbitalPeriod': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/orbits': 'http://www.w3.org/2001/XMLSchema#integer',
#  'http://dbpedia.org/ontology/orcidId': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/orderDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/orderInOffice': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/originalMaximumBoatBeam': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/originalMaximumBoatLength': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/originallyUsedFor': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/other': 'http://www.w3.org/2001/XMLSchema#integer',
#  'http://dbpedia.org/ontology/otherChannel': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/otherName': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString',
#  'http://dbpedia.org/ontology/otherServingLines': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/otherWins': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/overallRecord': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/oversight': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/parkingInformation': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/partialFailedLaunches': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/participant': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/passengersPerDay': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/passengersPerYear': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/passengersUsedSystem': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/pdb': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/percentageOfAreaWater': 'http://www.w3.org/2001/XMLSchema#float',
#  'http://dbpedia.org/ontology/periapsis': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/personName': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/pistonStroke': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/plays': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/podiums': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/poles': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/populationAsOf': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/populationDensity': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/populationMetro': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/populationMetroDensity': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/populationRural': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/populationTotal': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/populationTotalRanking': 'http://www.w3.org/2001/XMLSchema#positiveInteger',
#  'http://dbpedia.org/ontology/populationUrban': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/populationUrbanDensity': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/portfolio': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/postalCode': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/powerOutput': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/premiereDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/premiereYear': 'http://www.w3.org/2001/XMLSchema#gYear',
# ...
#  'http://dbpedia.org/ontology/productionStartDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/productionStartYear': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/programCost': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/projectBudgetFunding': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/projectBudgetTotal': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/projectEndDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/projectKeyword': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/projectStartDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/prominence': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/protein': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/pseudonym': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString',
#  'http://dbpedia.org/ontology/pubchem': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/publicationDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/publiclyAccessible': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/purpose': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/quote': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/races': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/railGauge': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/railwayPlatforms': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/rankInFinalMedalCount': 'http://www.w3.org/2001/XMLSchema#positiveInteger',
#  'http://dbpedia.org/ontology/ranking': 'http://www.w3.org/2001/XMLSchema#positiveInteger',
#  'http://dbpedia.org/ontology/rankingWins': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/rating': 'http://www.w3.org/2001/XMLSchema#float',
#  'http://dbpedia.org/ontology/rebuildDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/rebuildingDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/rebuildingYear': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/recommissioningDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/recordDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/refseq': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/refseqmrna': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/refseqprotein': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/releaseDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/reopeningDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/reopeningYear': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/reportingMark': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/reservations': 'http://www.w3.org/2001/XMLSchema#boolean',
#  'http://dbpedia.org/ontology/restoreDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/result': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/retired': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/revenue': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/review': 'http://www.w3.org/2001/XMLSchema#anyURI',
#  'http://dbpedia.org/ontology/rgbCoordinateBlue': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/rgbCoordinateGreen': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/rgbCoordinateRed': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/rkdArtistsId': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/rocketStages': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/role': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/rotationPeriod': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/routeEndDirection': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/routeNumber': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/routeStartDirection': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/routeTypeAbbreviation': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/runtime': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/runwayDesignation': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/runwayLength': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/runwaySurface': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/salary': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/satellitesDeployed': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/schoolCode': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/schoolNumber': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/seasonNumber': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/seatingCapacity': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/selibrId': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/seniority': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/serviceEndYear': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/serviceNumber': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/serviceStartYear': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/servingSize': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/servingTemperature': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/settingOfPlay': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/sex': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/shareDate': 'http://www.w3.org/2001/XMLSchema#gYearMonth',
#  'http://dbpedia.org/ontology/shareOfAudience': 'http://www.w3.org/2001/XMLSchema#float',
#  'http://dbpedia.org/ontology/shareSource': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/shipBeam': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/shipDisplacement': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/shipDraft': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/shipLaunch': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/shoeNumber': 'http://www.w3.org/2001/XMLSchema#positiveInteger',
#  'http://dbpedia.org/ontology/shoeSize': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/shoots': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/shoreLength': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/signature': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/sixthFormStudents': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/slogan': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString',
#  'http://dbpedia.org/ontology/sourceConfluenceElevation': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/sourceElevation': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/speaker': 'http://www.w3.org/2001/XMLSchema#integer',
#  'http://dbpedia.org/ontology/specialist': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/speedLimit': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/spike': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/squadNumber': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/staff': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/startDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/startYearOfInsertion': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/startYearOfSales': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/stationStructure': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/statisticValue': 'http://www.w3.org/2001/XMLSchema#float',
#  'http://dbpedia.org/ontology/statisticYear': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/status': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/strength': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/subdivisions': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/subjectOfPlay': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/suborbitalFlights': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/subtitle': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/successfulLaunches': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/sudocId': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/supplementalDraftRound': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/supplementalDraftYear': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/suppreddedDate': 'http://www.w3.org/2001/XMLSchema#date',
#  'http://dbpedia.org/ontology/surfaceArea': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/symbol': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/synonym': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/teamName': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString',
#  'http://dbpedia.org/ontology/teamSize': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/temperature': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/tennisSurfaceType': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/testaverage': 'http://www.w3.org/2001/XMLSchema#float',
#  'http://dbpedia.org/ontology/throwingSide': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/time': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/timeInSpace': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/timeshiftChannel': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/title': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#langString',
#  'http://dbpedia.org/ontology/toll': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/topSpeed': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/torqueOutput': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/totalLaunches': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/totalPopulation': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/totalTravellers': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/tournamentRecord': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/trackLength': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/trackNumber': 'http://www.w3.org/2001/XMLSchema#positiveInteger',
#  'http://dbpedia.org/ontology/transmission': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/tuition': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/uciCode': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/ulanId': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/undraftedYear': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/uniprot': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/unitCost': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/unitedStatesNationalBridgeId': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/upperAge': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/usSales': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/utcOffset': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/valvetrain': 'http://dbpedia.org/datatype/valvetrain',
#  'http://dbpedia.org/ontology/vehiclesPerDay': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/viafId': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/victims': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/virtualChannel': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/visitorStatisticsAsOf': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/visitorsPerYear': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/visitorsPercentageChange': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/voltageOfElectrification': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/volume': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/volumeQuote': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/waistSize': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/watershed': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/wavelength': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/weight': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/whaDraft': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/wheelbase': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/width': 'http://www.w3.org/2001/XMLSchema#double',
#  'http://dbpedia.org/ontology/widthQuote': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/wins': 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger',
#  'http://dbpedia.org/ontology/worldChampionTitleYear': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/worstDefeat': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://dbpedia.org/ontology/year': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/yearOfConstruction': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/yearOfElectrification': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://dbpedia.org/ontology/years': 'http://www.w3.org/2001/XMLSchema#gYear',
#  'http://purl.org/dc/elements/1.1/description': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://purl.org/dc/elements/1.1/publisher': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://purl.org/dc/elements/1.1/type': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://www.w3.org/2003/01/geo/wgs84_pos#lat': 'http://www.w3.org/2001/XMLSchema#float',
#  'http://www.w3.org/2003/01/geo/wgs84_pos#long': 'http://www.w3.org/2001/XMLSchema#float',
#  'http://xmlns.com/foaf/0.1/familyName': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://xmlns.com/foaf/0.1/givenName': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://xmlns.com/foaf/0.1/name': 'http://www.w3.org/2001/XMLSchema#string',
#  'http://xmlns.com/foaf/0.1/nick': 'http://www.w3.org/2001/XMLSchema#string'}

# %%
relations_valid
# Out:
# {'http://dbpedia.org/ontology/absoluteMagnitude',
#  'http://dbpedia.org/ontology/acceleration',
#  'http://dbpedia.org/ontology/acquirementDate',
#  'http://dbpedia.org/ontology/activeYearsEndDate',
#  'http://dbpedia.org/ontology/activeYearsEndYear',
#  'http://dbpedia.org/ontology/activeYearsStartDate',
#  'http://dbpedia.org/ontology/activeYearsStartYear',
#  'http://dbpedia.org/ontology/added',
#  'http://dbpedia.org/ontology/ageRange',
#  'http://dbpedia.org/ontology/albedo',
#  'http://dbpedia.org/ontology/anniversary',
#  'http://dbpedia.org/ontology/apoapsis',
#  'http://dbpedia.org/ontology/apparentMagnitude',
#  'http://dbpedia.org/ontology/approximateCalories',
#  'http://dbpedia.org/ontology/area',
#  'http://dbpedia.org/ontology/areaLand',
#  'http://dbpedia.org/ontology/areaMetro',
#  'http://dbpedia.org/ontology/areaOfCatchment',
#  'http://dbpedia.org/ontology/areaRural',
#  'http://dbpedia.org/ontology/areaTotal',
#  'http://dbpedia.org/ontology/areaUrban',
#  'http://dbpedia.org/ontology/areaWater',
#  'http://dbpedia.org/ontology/argueDate',
#  'http://dbpedia.org/ontology/assetUnderManagement',
#  'http://dbpedia.org/ontology/assets',
#  'http://dbpedia.org/ontology/averageAnnualGeneration',
#  'http://dbpedia.org/ontology/averageClassSize',
#  'http://dbpedia.org/ontology/averageDepth',
#  'http://dbpedia.org/ontology/averageSpeed',
#  'http://dbpedia.org/ontology/barPassRate',
#  'http://dbpedia.org/ontology/beatifiedDate',
#  'http://dbpedia.org/ontology/bedCount',
#  'http://dbpedia.org/ontology/bioavailability',
#  'http://dbpedia.org/ontology/birthDate',
#  'http://dbpedia.org/ontology/birthYear',
#  'http://dbpedia.org/ontology/budget',
#  'http://dbpedia.org/ontology/buildingEndYear',
#  'http://dbpedia.org/ontology/buildingStartYear',
#  'http://dbpedia.org/ontology/bustSize',
#  'http://dbpedia.org/ontology/campusSize',
#  'http://dbpedia.org/ontology/canonizedDate',
#  'http://dbpedia.org/ontology/capacity',
#  'http://dbpedia.org/ontology/capacityFactor',
#  'http://dbpedia.org/ontology/capitalElevation',
#  'http://dbpedia.org/ontology/captureDate',
#  'http://dbpedia.org/ontology/carNumber',
#  'http://dbpedia.org/ontology/carbohydrate',
#  'http://dbpedia.org/ontology/careerPrizeMoney',
#  'http://dbpedia.org/ontology/casualties',
#  'http://dbpedia.org/ontology/censusYear',
#  'http://dbpedia.org/ontology/centuryBreaks',
#  'http://dbpedia.org/ontology/certificationDate',
#  'http://dbpedia.org/ontology/championships',
#  'http://dbpedia.org/ontology/christeningDate',
#  'http://dbpedia.org/ontology/circulation',
#  'http://dbpedia.org/ontology/classes',
#  'http://dbpedia.org/ontology/closed',
#  'http://dbpedia.org/ontology/closingDate',
#  'http://dbpedia.org/ontology/closingYear',
#  'http://dbpedia.org/ontology/cmykCoordinateBlack',
#  'http://dbpedia.org/ontology/cmykCoordinateCyanic',
#  'http://dbpedia.org/ontology/cmykCoordinateMagenta',
#  'http://dbpedia.org/ontology/cmykCoordinateYellow',
#  'http://dbpedia.org/ontology/co2Emission',
#  'http://dbpedia.org/ontology/commissioningDate',
#  'http://dbpedia.org/ontology/completionDate',
#  'http://dbpedia.org/ontology/contractAward',
#  'http://dbpedia.org/ontology/cost',
#  'http://dbpedia.org/ontology/course',
#  'http://dbpedia.org/ontology/crews',
#  'http://dbpedia.org/ontology/currentRank',
#  'http://dbpedia.org/ontology/cylinderBore',
#  'http://dbpedia.org/ontology/cylinderCount',
#  'http://dbpedia.org/ontology/date',
#  'http://dbpedia.org/ontology/dateAct',
#  'http://dbpedia.org/ontology/dateCompleted',
#  'http://dbpedia.org/ontology/dateConstruction',
#  'http://dbpedia.org/ontology/dateOfAbandonment',
#  'http://dbpedia.org/ontology/dateOfBurial',
#  'http://dbpedia.org/ontology/dateUse',
#  'http://dbpedia.org/ontology/day',
#  'http://dbpedia.org/ontology/deathDate',
#  'http://dbpedia.org/ontology/deathYear',
#  'http://dbpedia.org/ontology/debut',
#  'http://dbpedia.org/ontology/decideDate',
#  'http://dbpedia.org/ontology/declination',
#  'http://dbpedia.org/ontology/decommissioningDate',
#  'http://dbpedia.org/ontology/deliveryDate',
#  'http://dbpedia.org/ontology/demolitionDate',
#  'http://dbpedia.org/ontology/demolitionYear',
#  'http://dbpedia.org/ontology/density',
#  'http://dbpedia.org/ontology/depth',
#  'http://dbpedia.org/ontology/destructionDate',
#  'http://dbpedia.org/ontology/diameter',
#  'http://dbpedia.org/ontology/disbanded',
#  'http://dbpedia.org/ontology/discharge',
#  'http://dbpedia.org/ontology/dischargeAverage',
#  'http://dbpedia.org/ontology/discovered',
#  'http://dbpedia.org/ontology/displacement',
#  'http://dbpedia.org/ontology/dissolutionDate',
#  'http://dbpedia.org/ontology/dissolutionYear',
#  'http://dbpedia.org/ontology/dissolved',
#  'http://dbpedia.org/ontology/distance',
#  'http://dbpedia.org/ontology/distanceLaps',
#  'http://dbpedia.org/ontology/distanceToBelfast',
#  'http://dbpedia.org/ontology/distanceToCardiff',
#  'http://dbpedia.org/ontology/distanceToCharingCross',
#  'http://dbpedia.org/ontology/distanceToDouglas',
#  'http://dbpedia.org/ontology/distanceToDublin',
#  'http://dbpedia.org/ontology/distanceToEdinburgh',
#  'http://dbpedia.org/ontology/distanceToLondon',
#  'http://dbpedia.org/ontology/draftYear',
#  'http://dbpedia.org/ontology/duration',
#  'http://dbpedia.org/ontology/effectiveRadiatedPower',
#  'http://dbpedia.org/ontology/electionDate',
#  'http://dbpedia.org/ontology/electionDateLeader',
#  'http://dbpedia.org/ontology/electionMajority',
#  'http://dbpedia.org/ontology/elevation',
#  'http://dbpedia.org/ontology/endDate',
#  'http://dbpedia.org/ontology/endYearOfInsertion',
#  'http://dbpedia.org/ontology/endYearOfSales',
#  'http://dbpedia.org/ontology/endowment',
#  'http://dbpedia.org/ontology/episodeNumber',
#  'http://dbpedia.org/ontology/equity',
#  'http://dbpedia.org/ontology/eruptionYear',
#  'http://dbpedia.org/ontology/escapeVelocity',
#  'http://dbpedia.org/ontology/espnId',
#  'http://dbpedia.org/ontology/ethnicGroupsInYear',
#  'http://dbpedia.org/ontology/extinctionDate',
#  'http://dbpedia.org/ontology/extinctionYear',
#  'http://dbpedia.org/ontology/facilityId',
#  'http://dbpedia.org/ontology/facultySize',
#  'http://dbpedia.org/ontology/failedLaunches',
#  'http://dbpedia.org/ontology/fastestLap',
#  'http://dbpedia.org/ontology/fat',
#  'http://dbpedia.org/ontology/feastDay',
#  'http://dbpedia.org/ontology/fees',
#  'http://dbpedia.org/ontology/fileSize',
#  'http://dbpedia.org/ontology/finalFlight',
#  'http://dbpedia.org/ontology/finalPublicationYear',
#  'http://dbpedia.org/ontology/firstAirDate',
#  'http://dbpedia.org/ontology/firstAscentYear',
#  'http://dbpedia.org/ontology/firstFlightEndDate',
#  'http://dbpedia.org/ontology/firstFlightStartDate',
#  'http://dbpedia.org/ontology/firstLaunchDate',
#  'http://dbpedia.org/ontology/firstPublicationDate',
#  'http://dbpedia.org/ontology/firstPublicationYear',
#  'http://dbpedia.org/ontology/floodingDate',
#  'http://dbpedia.org/ontology/floorArea',
#  'http://dbpedia.org/ontology/floorCount',
#  'http://dbpedia.org/ontology/foalDate',
#  'http://dbpedia.org/ontology/formationDate',
#  'http://dbpedia.org/ontology/formationYear',
#  'http://dbpedia.org/ontology/foundingDate',
#  'http://dbpedia.org/ontology/foundingYear',
#  'http://dbpedia.org/ontology/frequency',
#  'http://dbpedia.org/ontology/fuelCapacity',
#  'http://dbpedia.org/ontology/geneLocationEnd',
#  'http://dbpedia.org/ontology/geneLocationStart',
#  'http://dbpedia.org/ontology/glycemicIndex',
#  'http://dbpedia.org/ontology/governmentElevation',
#  'http://dbpedia.org/ontology/grayPage',
#  'http://dbpedia.org/ontology/graySubject',
#  'http://dbpedia.org/ontology/gross',
#  'http://dbpedia.org/ontology/grossDomesticProduct',
#  'http://dbpedia.org/ontology/height',
#  'http://dbpedia.org/ontology/heightAboveAverageTerrain',
#  'http://dbpedia.org/ontology/highestBreak',
#  'http://dbpedia.org/ontology/highestRank',
#  'http://dbpedia.org/ontology/hipSize',
#  'http://dbpedia.org/ontology/hsvCoordinateHue',
#  'http://dbpedia.org/ontology/hsvCoordinateSaturation',
#  'http://dbpedia.org/ontology/hsvCoordinateValue',
#  'http://dbpedia.org/ontology/imageSize',
#  'http://dbpedia.org/ontology/impactFactor',
#  'http://dbpedia.org/ontology/impactFactorAsOf',
#  'http://dbpedia.org/ontology/installedCapacity',
#  'http://dbpedia.org/ontology/introduced',
#  'http://dbpedia.org/ontology/introductionDate',
#  'http://dbpedia.org/ontology/issDockings',
#  'http://dbpedia.org/ontology/lastAirDate',
#  'http://dbpedia.org/ontology/lastElectionDate',
#  'http://dbpedia.org/ontology/lastFlightEndDate',
#  'http://dbpedia.org/ontology/lastFlightStartDate',
#  'http://dbpedia.org/ontology/lastLaunchDate',
#  'http://dbpedia.org/ontology/lastPosition',
#  'http://dbpedia.org/ontology/lastPublicationDate',
#  'http://dbpedia.org/ontology/latestPreviewDate',
#  'http://dbpedia.org/ontology/latestReleaseDate',
#  'http://dbpedia.org/ontology/launches',
#  'http://dbpedia.org/ontology/layingDown',
#  'http://dbpedia.org/ontology/length',
#  'http://dbpedia.org/ontology/lineLength',
#  'http://dbpedia.org/ontology/loadLimit',
#  'http://dbpedia.org/ontology/lowerAge',
#  'http://dbpedia.org/ontology/lowerEarthOrbitPayload',
#  'http://dbpedia.org/ontology/maidenFlight',
#  'http://dbpedia.org/ontology/maidenVoyage',
#  'http://dbpedia.org/ontology/mainspan',
#  'http://dbpedia.org/ontology/managementElevation',
#  'http://dbpedia.org/ontology/mass',
#  'http://dbpedia.org/ontology/maxTime',
#  'http://dbpedia.org/ontology/maximumBoatBeam',
#  'http://dbpedia.org/ontology/maximumBoatLength',
#  'http://dbpedia.org/ontology/maximumDepth',
#  'http://dbpedia.org/ontology/maximumDischarge',
#  'http://dbpedia.org/ontology/maximumElevation',
#  'http://dbpedia.org/ontology/maximumTemperature',
#  'http://dbpedia.org/ontology/meanRadius',
#  'http://dbpedia.org/ontology/meanTemperature',
#  'http://dbpedia.org/ontology/minTime',
#  'http://dbpedia.org/ontology/minimumDischarge',
#  'http://dbpedia.org/ontology/minimumElevation',
#  'http://dbpedia.org/ontology/minimumTemperature',
#  'http://dbpedia.org/ontology/mirDockings',
#  'http://dbpedia.org/ontology/missions',
#  'http://dbpedia.org/ontology/modelEndYear',
#  'http://dbpedia.org/ontology/modelStartYear',
#  'http://dbpedia.org/ontology/mouthElevation',
#  'http://dbpedia.org/ontology/nameDay',
#  'http://dbpedia.org/ontology/nationalRanking',
#  'http://dbpedia.org/ontology/netIncome',
#  'http://dbpedia.org/ontology/networth',
#  'http://dbpedia.org/ontology/numberBuilt',
#  'http://dbpedia.org/ontology/numberOfBronzeMedalsWon',
#  'http://dbpedia.org/ontology/numberOfCompetitors',
#  'http://dbpedia.org/ontology/numberOfDoctoralStudents',
#  'http://dbpedia.org/ontology/numberOfEmployees',
#  'http://dbpedia.org/ontology/numberOfEpisodes',
#  'http://dbpedia.org/ontology/numberOfFilms',
#  'http://dbpedia.org/ontology/numberOfGoals',
#  'http://dbpedia.org/ontology/numberOfGoldMedalsWon',
#  'http://dbpedia.org/ontology/numberOfGraduateStudents',
#  'http://dbpedia.org/ontology/numberOfIslands',
#  'http://dbpedia.org/ontology/numberOfLanes',
#  'http://dbpedia.org/ontology/numberOfLawyers',
#  'http://dbpedia.org/ontology/numberOfLines',
#  'http://dbpedia.org/ontology/numberOfLocations',
#  'http://dbpedia.org/ontology/numberOfMatches',
#  'http://dbpedia.org/ontology/numberOfMembers',
#  'http://dbpedia.org/ontology/numberOfOffices',
#  'http://dbpedia.org/ontology/numberOfOfficials',
#  'http://dbpedia.org/ontology/numberOfPads',
#  'http://dbpedia.org/ontology/numberOfPages',
#  'http://dbpedia.org/ontology/numberOfParkingSpaces',
#  'http://dbpedia.org/ontology/numberOfParticipatingAthletes',
#  'http://dbpedia.org/ontology/numberOfParticipatingNations',
#  'http://dbpedia.org/ontology/numberOfPiersInWater',
#  'http://dbpedia.org/ontology/numberOfPlatformLevels',
#  'http://dbpedia.org/ontology/numberOfPostgraduateStudents',
#  'http://dbpedia.org/ontology/numberOfRestaurants',
#  'http://dbpedia.org/ontology/numberOfRooms',
#  'http://dbpedia.org/ontology/numberOfSeasons',
#  'http://dbpedia.org/ontology/numberOfSilverMedalsWon',
#  'http://dbpedia.org/ontology/numberOfSpans',
#  'http://dbpedia.org/ontology/numberOfSports',
#  'http://dbpedia.org/ontology/numberOfStaff',
#  'http://dbpedia.org/ontology/numberOfStations',
#  'http://dbpedia.org/ontology/numberOfStudents',
#  'http://dbpedia.org/ontology/numberOfSuites',
#  'http://dbpedia.org/ontology/numberOfTeams',
#  'http://dbpedia.org/ontology/numberOfTracks',
#  'http://dbpedia.org/ontology/numberOfUndergraduateStudents',
#  'http://dbpedia.org/ontology/numberOfVehicles',
#  'http://dbpedia.org/ontology/numberOfVineyards',
#  'http://dbpedia.org/ontology/numberOfVisitors',
#  'http://dbpedia.org/ontology/numberOfVisitorsAsOf',
#  'http://dbpedia.org/ontology/numberOfVolumes',
#  'http://dbpedia.org/ontology/numberOfVolunteers',
#  'http://dbpedia.org/ontology/numberOfWineries',
#  'http://dbpedia.org/ontology/numberSold',
#  'http://dbpedia.org/ontology/omim',
#  'http://dbpedia.org/ontology/onChromosome',
#  'http://dbpedia.org/ontology/openingDate',
#  'http://dbpedia.org/ontology/openingYear',
#  'http://dbpedia.org/ontology/operatingIncome',
#  'http://dbpedia.org/ontology/orbitalFlights',
#  'http://dbpedia.org/ontology/orbitalPeriod',
#  'http://dbpedia.org/ontology/orbits',
#  'http://dbpedia.org/ontology/orderDate',
#  'http://dbpedia.org/ontology/originalMaximumBoatBeam',
#  'http://dbpedia.org/ontology/originalMaximumBoatLength',
#  'http://dbpedia.org/ontology/other',
#  'http://dbpedia.org/ontology/otherWins',
#  'http://dbpedia.org/ontology/partialFailedLaunches',
#  'http://dbpedia.org/ontology/passengersPerDay',
#  'http://dbpedia.org/ontology/passengersPerYear',
#  'http://dbpedia.org/ontology/percentageOfAreaWater',
#  'http://dbpedia.org/ontology/periapsis',
#  'http://dbpedia.org/ontology/pistonStroke',
#  'http://dbpedia.org/ontology/podiums',
#  'http://dbpedia.org/ontology/poles',
#  'http://dbpedia.org/ontology/populationAsOf',
#  'http://dbpedia.org/ontology/populationDensity',
#  'http://dbpedia.org/ontology/populationMetro',
#  'http://dbpedia.org/ontology/populationMetroDensity',
#  'http://dbpedia.org/ontology/populationRural',
#  'http://dbpedia.org/ontology/populationTotal',
#  'http://dbpedia.org/ontology/populationTotalRanking',
#  'http://dbpedia.org/ontology/populationUrban',
#  'http://dbpedia.org/ontology/populationUrbanDensity',
#  'http://dbpedia.org/ontology/powerOutput',
#  'http://dbpedia.org/ontology/premiereDate',
#  'http://dbpedia.org/ontology/premiereYear',
#  'http://dbpedia.org/ontology/production',
#  'http://dbpedia.org/ontology/productionEndDate',
#  'http://dbpedia.org/ontology/productionEndYear',
#  'http://dbpedia.org/ontology/productionStartDate',
#  'http://dbpedia.org/ontology/productionStartYear',
#  'http://dbpedia.org/ontology/programCost',
#  'http://dbpedia.org/ontology/projectBudgetFunding',
#  'http://dbpedia.org/ontology/projectBudgetTotal',
#  'http://dbpedia.org/ontology/projectEndDate',
#  'http://dbpedia.org/ontology/projectStartDate',
#  'http://dbpedia.org/ontology/prominence',
#  'http://dbpedia.org/ontology/protein',
#  'http://dbpedia.org/ontology/publicationDate',
#  'http://dbpedia.org/ontology/races',
#  'http://dbpedia.org/ontology/railGauge',
#  'http://dbpedia.org/ontology/rankInFinalMedalCount',
#  'http://dbpedia.org/ontology/ranking',
#  'http://dbpedia.org/ontology/rankingWins',
#  'http://dbpedia.org/ontology/rating',
#  'http://dbpedia.org/ontology/rebuildDate',
#  'http://dbpedia.org/ontology/rebuildingDate',
#  'http://dbpedia.org/ontology/rebuildingYear',
#  'http://dbpedia.org/ontology/recommissioningDate',
#  'http://dbpedia.org/ontology/recordDate',
#  'http://dbpedia.org/ontology/releaseDate',
#  'http://dbpedia.org/ontology/reopeningDate',
#  'http://dbpedia.org/ontology/reopeningYear',
#  'http://dbpedia.org/ontology/restoreDate',
#  'http://dbpedia.org/ontology/retired',
#  'http://dbpedia.org/ontology/revenue',
#  'http://dbpedia.org/ontology/rgbCoordinateBlue',
#  'http://dbpedia.org/ontology/rgbCoordinateGreen',
#  'http://dbpedia.org/ontology/rgbCoordinateRed',
#  'http://dbpedia.org/ontology/rocketStages',
#  'http://dbpedia.org/ontology/rotationPeriod',
#  'http://dbpedia.org/ontology/runtime',
#  'http://dbpedia.org/ontology/runwayLength',
#  'http://dbpedia.org/ontology/salary',
#  'http://dbpedia.org/ontology/satellitesDeployed',
#  'http://dbpedia.org/ontology/seasonNumber',
#  'http://dbpedia.org/ontology/seatingCapacity',
#  'http://dbpedia.org/ontology/serviceEndYear',
#  'http://dbpedia.org/ontology/serviceStartYear',
#  'http://dbpedia.org/ontology/servingSize',
#  'http://dbpedia.org/ontology/shareDate',
#  'http://dbpedia.org/ontology/shareOfAudience',
#  'http://dbpedia.org/ontology/shipBeam',
#  'http://dbpedia.org/ontology/shipDisplacement',
#  'http://dbpedia.org/ontology/shipDraft',
#  'http://dbpedia.org/ontology/shipLaunch',
#  'http://dbpedia.org/ontology/shoeNumber',
#  'http://dbpedia.org/ontology/shoreLength',
#  'http://dbpedia.org/ontology/sourceConfluenceElevation',
#  'http://dbpedia.org/ontology/sourceElevation',
#  'http://dbpedia.org/ontology/speaker',
#  'http://dbpedia.org/ontology/speedLimit',
#  'http://dbpedia.org/ontology/squadNumber',
#  'http://dbpedia.org/ontology/staff',
#  'http://dbpedia.org/ontology/startDate',
#  'http://dbpedia.org/ontology/startYearOfInsertion',
#  'http://dbpedia.org/ontology/startYearOfSales',
#  'http://dbpedia.org/ontology/statisticValue',
#  'http://dbpedia.org/ontology/statisticYear',
#  'http://dbpedia.org/ontology/subdivisions',
#  'http://dbpedia.org/ontology/suborbitalFlights',
#  'http://dbpedia.org/ontology/successfulLaunches',
#  'http://dbpedia.org/ontology/supplementalDraftYear',
#  'http://dbpedia.org/ontology/suppreddedDate',
#  'http://dbpedia.org/ontology/surfaceArea',
#  'http://dbpedia.org/ontology/teamSize',
#  'http://dbpedia.org/ontology/temperature',
#  'http://dbpedia.org/ontology/testaverage',
#  'http://dbpedia.org/ontology/timeInSpace',
#  'http://dbpedia.org/ontology/toll',
#  'http://dbpedia.org/ontology/topSpeed',
#  'http://dbpedia.org/ontology/torqueOutput',
#  'http://dbpedia.org/ontology/totalLaunches',
#  'http://dbpedia.org/ontology/totalPopulation',
#  'http://dbpedia.org/ontology/totalTravellers',
#  'http://dbpedia.org/ontology/trackLength',
#  'http://dbpedia.org/ontology/trackNumber',
#  'http://dbpedia.org/ontology/tuition',
#  'http://dbpedia.org/ontology/undraftedYear',
#  'http://dbpedia.org/ontology/unitCost',
#  'http://dbpedia.org/ontology/upperAge',
#  'http://dbpedia.org/ontology/usSales',
#  'http://dbpedia.org/ontology/vehiclesPerDay',
#  'http://dbpedia.org/ontology/visitorStatisticsAsOf',
#  'http://dbpedia.org/ontology/visitorsPerYear',
#  'http://dbpedia.org/ontology/visitorsPercentageChange',
#  'http://dbpedia.org/ontology/voltageOfElectrification',
#  'http://dbpedia.org/ontology/volume',
#  'http://dbpedia.org/ontology/waistSize',
#  'http://dbpedia.org/ontology/watershed',
#  'http://dbpedia.org/ontology/wavelength',
#  'http://dbpedia.org/ontology/weight',
#  'http://dbpedia.org/ontology/wheelbase',
#  'http://dbpedia.org/ontology/width',
#  'http://dbpedia.org/ontology/wins',
#  'http://dbpedia.org/ontology/year',
#  'http://dbpedia.org/ontology/yearOfConstruction',
#  'http://dbpedia.org/ontology/yearOfElectrification',
#  'http://dbpedia.org/ontology/years',
#  'http://www.w3.org/2003/01/geo/wgs84_pos#lat',
#  'http://www.w3.org/2003/01/geo/wgs84_pos#long'}

# %%
relations_invalid
# Out:
# {'http://dbpedia.org/ontology/aSide',
#  'http://dbpedia.org/ontology/abbreviation',
#  'http://dbpedia.org/ontology/access',
#  'http://dbpedia.org/ontology/activeYears',
#  'http://dbpedia.org/ontology/address',
#  'http://dbpedia.org/ontology/agencyStationCode',
#  'http://dbpedia.org/ontology/alias',
#  'http://dbpedia.org/ontology/allegiance',
#  'http://dbpedia.org/ontology/alternativeName',
#  'http://dbpedia.org/ontology/analogChannel',
#  'http://dbpedia.org/ontology/areaCode',
#  'http://dbpedia.org/ontology/areaOfCatchmentQuote',
#  'http://dbpedia.org/ontology/areaQuote',
#  'http://dbpedia.org/ontology/arm',
#  'http://dbpedia.org/ontology/atcPrefix',
#  'http://dbpedia.org/ontology/atcSuffix',
#  'http://dbpedia.org/ontology/atcSupplemental',
#  'http://dbpedia.org/ontology/automobileModel',
#  'http://dbpedia.org/ontology/averageDepthQuote',
#  'http://dbpedia.org/ontology/bSide',
#  'http://dbpedia.org/ontology/background',
#  'http://dbpedia.org/ontology/band',
#  'http://dbpedia.org/ontology/battingSide',
#  'http://dbpedia.org/ontology/battleHonours',
#  'http://dbpedia.org/ontology/bestFinish',
#  'http://dbpedia.org/ontology/bibsysId',
#  'http://dbpedia.org/ontology/bicycleInformation',
#  'http://dbpedia.org/ontology/birthName',
#  'http://dbpedia.org/ontology/block',
#  'http://dbpedia.org/ontology/bnfId',
#  'http://dbpedia.org/ontology/bowlRecord',
#  'http://dbpedia.org/ontology/bpnId',
#  'http://dbpedia.org/ontology/brainInfoNumber',
#  'http://dbpedia.org/ontology/brainInfoType',
#  'http://dbpedia.org/ontology/bridgeCarries',
#  'http://dbpedia.org/ontology/broadcastRepeater',
#  'http://dbpedia.org/ontology/broadcastStationClass',
#  'http://dbpedia.org/ontology/broadcastTranslator',
#  'http://dbpedia.org/ontology/buildingEndDate',
#  'http://dbpedia.org/ontology/buildingStartDate',
#  'http://dbpedia.org/ontology/callSign',
#  'http://dbpedia.org/ontology/callsignMeaning',
#  'http://dbpedia.org/ontology/campusType',
#  'http://dbpedia.org/ontology/canBaggageChecked',
#  'http://dbpedia.org/ontology/casNumber',
#  'http://dbpedia.org/ontology/casSupplemental',
#  'http://dbpedia.org/ontology/causalties',
#  'http://dbpedia.org/ontology/ceeb',
#  'http://dbpedia.org/ontology/certification',
#  'http://dbpedia.org/ontology/chEBI',
#  'http://dbpedia.org/ontology/chairmanTitle',
#  'http://dbpedia.org/ontology/characterInPlay',
#  'http://dbpedia.org/ontology/chorusCharacterInPlay',
#  'http://dbpedia.org/ontology/chromosome',
#  'http://dbpedia.org/ontology/cityType',
#  'http://dbpedia.org/ontology/coachingRecord',
#  'http://dbpedia.org/ontology/code',
#  'http://dbpedia.org/ontology/coden',
#  'http://dbpedia.org/ontology/collection',
#  'http://dbpedia.org/ontology/colourHexCode',
#  'http://dbpedia.org/ontology/colourName',
#  'http://dbpedia.org/ontology/combatant',
#  'http://dbpedia.org/ontology/committee',
#  'http://dbpedia.org/ontology/commonName',
#  'http://dbpedia.org/ontology/complexity',
#  'http://dbpedia.org/ontology/compressionRatio',
#  'http://dbpedia.org/ontology/configuration',
#  'http://dbpedia.org/ontology/conservationStatus',
#  'http://dbpedia.org/ontology/conservationStatusSystem',
#  'http://dbpedia.org/ontology/cosparId',
#  'http://dbpedia.org/ontology/crownDependency',
#  'http://dbpedia.org/ontology/cuisine',
#  'http://dbpedia.org/ontology/currentRecord',
#  'http://dbpedia.org/ontology/currentSeason',
#  'http://dbpedia.org/ontology/currentStatus',
#  'http://dbpedia.org/ontology/currentlyUsedFor',
#  'http://dbpedia.org/ontology/dcc',
#  'http://dbpedia.org/ontology/demonym',
#  'http://dbpedia.org/ontology/depictionDescription',
#  'http://dbpedia.org/ontology/description',
#  'http://dbpedia.org/ontology/detectionMethod',
#  'http://dbpedia.org/ontology/digitalChannel',
#  'http://dbpedia.org/ontology/digitalSubChannel',
#  'http://dbpedia.org/ontology/dorlandsPrefix',
#  'http://dbpedia.org/ontology/dorlandsSuffix',
#  'http://dbpedia.org/ontology/draft',
#  'http://dbpedia.org/ontology/draftPick',
#  'http://dbpedia.org/ontology/draftRound',
#  'http://dbpedia.org/ontology/dressCode',
#  'http://dbpedia.org/ontology/drugbank',
#  'http://dbpedia.org/ontology/ecNumber',
#  'http://dbpedia.org/ontology/editorTitle',
#  'http://dbpedia.org/ontology/elevationQuote',
#  'http://dbpedia.org/ontology/ensembl',
#  'http://dbpedia.org/ontology/entrezgene',
#  'http://dbpedia.org/ontology/epoch',
#  'http://dbpedia.org/ontology/established',
#  'http://dbpedia.org/ontology/eyeColor',
#  'http://dbpedia.org/ontology/faaLocationIdentifier',
#  'http://dbpedia.org/ontology/fansgroup',
#  'http://dbpedia.org/ontology/fareZone',
#  'http://dbpedia.org/ontology/fate',
#  'http://dbpedia.org/ontology/fdaUniiCode',
#  'http://dbpedia.org/ontology/filename',
#  'http://dbpedia.org/ontology/firstAppearance',
#  'http://dbpedia.org/ontology/firstGame',
#  'http://dbpedia.org/ontology/flag',
#  'http://dbpedia.org/ontology/formerCallsign',
#  'http://dbpedia.org/ontology/formerChannel',
#  'http://dbpedia.org/ontology/formerName',
#  'http://dbpedia.org/ontology/frequencyOfPublication',
#  'http://dbpedia.org/ontology/frequentlyUpdated',
#  'http://dbpedia.org/ontology/frozen',
#  'http://dbpedia.org/ontology/fuelConsumption',
#  'http://dbpedia.org/ontology/fuelType',
#  'http://dbpedia.org/ontology/games',
#  'http://dbpedia.org/ontology/gasChambers',
#  'http://dbpedia.org/ontology/generationUnits',
#  'http://dbpedia.org/ontology/genomeDB',
#  'http://dbpedia.org/ontology/geologicPeriod',
#  'http://dbpedia.org/ontology/geology',
#  'http://dbpedia.org/ontology/gridReference',
#  'http://dbpedia.org/ontology/hairColor',
#  'http://dbpedia.org/ontology/hallOfFame',
#  'http://dbpedia.org/ontology/headLabel',
#  'http://dbpedia.org/ontology/hgncid',
#  'http://dbpedia.org/ontology/iataAirlineCode',
#  'http://dbpedia.org/ontology/iataLocationIdentifier',
#  'http://dbpedia.org/ontology/ibdbId',
#  'http://dbpedia.org/ontology/icaoAirlineCode',
#  'http://dbpedia.org/ontology/icaoLocationIdentifier',
#  'http://dbpedia.org/ontology/icd10',
#  'http://dbpedia.org/ontology/icd9',
#  'http://dbpedia.org/ontology/icdo',
#  'http://dbpedia.org/ontology/id',
#  'http://dbpedia.org/ontology/identificationSymbol',
#  'http://dbpedia.org/ontology/imdbId',
#  'http://dbpedia.org/ontology/individualisedGnd',
#  'http://dbpedia.org/ontology/ingredientName',
#  'http://dbpedia.org/ontology/inseeCode',
#  'http://dbpedia.org/ontology/interest',
#  'http://dbpedia.org/ontology/internationally',
#  'http://dbpedia.org/ontology/isHandicappedAccessible',
#  'http://dbpedia.org/ontology/isPartOfName',
#  'http://dbpedia.org/ontology/isPeerReviewed',
#  'http://dbpedia.org/ontology/isbn',
#  'http://dbpedia.org/ontology/isniId',
#  'http://dbpedia.org/ontology/iso6391Code',
#  'http://dbpedia.org/ontology/iso6392Code',
#  'http://dbpedia.org/ontology/iso6393Code',
#  'http://dbpedia.org/ontology/isoCodeRegion',
#  'http://dbpedia.org/ontology/issn',
#  'http://dbpedia.org/ontology/iucnCategory',
#  'http://dbpedia.org/ontology/iupacName',
#  'http://dbpedia.org/ontology/jstor',
#  'http://dbpedia.org/ontology/largestWin',
#  'http://dbpedia.org/ontology/latestPreviewVersion',
#  'http://dbpedia.org/ontology/latestReleaseVersion',
#  'http://dbpedia.org/ontology/lcc',
#  'http://dbpedia.org/ontology/lccn',
#  'http://dbpedia.org/ontology/lccnId',
#  'http://dbpedia.org/ontology/leaderTitle',
#  'http://dbpedia.org/ontology/legislativePeriodName',
#  'http://dbpedia.org/ontology/lengthQuote',
#  'http://dbpedia.org/ontology/lengthReference',
#  'http://dbpedia.org/ontology/liberationDate',
#  'http://dbpedia.org/ontology/licensee',
#  'http://dbpedia.org/ontology/locationIdentifier',
#  'http://dbpedia.org/ontology/locusSupplementaryData',
#  'http://dbpedia.org/ontology/logo',
#  'http://dbpedia.org/ontology/longName',
#  'http://dbpedia.org/ontology/longtype',
#  'http://dbpedia.org/ontology/lowest',
#  'http://dbpedia.org/ontology/managerTitle',
#  'http://dbpedia.org/ontology/mapCaption',
#  'http://dbpedia.org/ontology/mascot',
#  'http://dbpedia.org/ontology/material',
#  'http://dbpedia.org/ontology/maximumDepthQuote',
#  'http://dbpedia.org/ontology/mbaId',
#  'http://dbpedia.org/ontology/meaning',
#  'http://dbpedia.org/ontology/membership',
#  'http://dbpedia.org/ontology/meshId',
#  'http://dbpedia.org/ontology/meshName',
#  'http://dbpedia.org/ontology/meshNumber',
#  'http://dbpedia.org/ontology/mgiid',
#  'http://dbpedia.org/ontology/militaryCommand',
#  'http://dbpedia.org/ontology/militaryUnitSize',
#  'http://dbpedia.org/ontology/model',
#  'http://dbpedia.org/ontology/month',
#  'http://dbpedia.org/ontology/motto',
#  'http://dbpedia.org/ontology/municipalityCode',
#  'http://dbpedia.org/ontology/muteCharacterInPlay',
#  'http://dbpedia.org/ontology/name',
#  'http://dbpedia.org/ontology/nationalTopographicSystemMapNumber',
#  'http://dbpedia.org/ontology/ndlId',
#  'http://dbpedia.org/ontology/neighbourConstellations',
#  'http://dbpedia.org/ontology/nlaId',
#  'http://dbpedia.org/ontology/note',
#  'http://dbpedia.org/ontology/notes',
#  'http://dbpedia.org/ontology/nrhpReferenceNumber',
#  'http://dbpedia.org/ontology/nssdcId',
#  'http://dbpedia.org/ontology/number',
#  'http://dbpedia.org/ontology/numberOfDeaths',
#  'http://dbpedia.org/ontology/nutsCode',
#  'http://dbpedia.org/ontology/oclc',
#  'http://dbpedia.org/ontology/offeredClasses',
#  'http://dbpedia.org/ontology/office',
#  'http://dbpedia.org/ontology/officialSchoolColour',
#  'http://dbpedia.org/ontology/oldcode',
#  'http://dbpedia.org/ontology/openAccessContent',
#  'http://dbpedia.org/ontology/orcidId',
#  'http://dbpedia.org/ontology/orderInOffice',
#  'http://dbpedia.org/ontology/originallyUsedFor',
#  'http://dbpedia.org/ontology/otherChannel',
#  'http://dbpedia.org/ontology/otherName',
#  'http://dbpedia.org/ontology/otherServingLines',
#  'http://dbpedia.org/ontology/overallRecord',
#  'http://dbpedia.org/ontology/oversight',
#  'http://dbpedia.org/ontology/parkingInformation',
#  'http://dbpedia.org/ontology/participant',
#  'http://dbpedia.org/ontology/passengersUsedSystem',
#  'http://dbpedia.org/ontology/pdb',
#  'http://dbpedia.org/ontology/personName',
#  'http://dbpedia.org/ontology/plays',
#  'http://dbpedia.org/ontology/portfolio',
#  'http://dbpedia.org/ontology/postalCode',
#  'http://dbpedia.org/ontology/projectKeyword',
#  'http://dbpedia.org/ontology/pseudonym',
#  'http://dbpedia.org/ontology/pubchem',
#  'http://dbpedia.org/ontology/publiclyAccessible',
#  'http://dbpedia.org/ontology/purpose',
#  'http://dbpedia.org/ontology/quote',
#  'http://dbpedia.org/ontology/railwayPlatforms',
#  'http://dbpedia.org/ontology/refseq',
#  'http://dbpedia.org/ontology/refseqmrna',
#  'http://dbpedia.org/ontology/refseqprotein',
#  'http://dbpedia.org/ontology/reportingMark',
#  'http://dbpedia.org/ontology/reservations',
#  'http://dbpedia.org/ontology/result',
#  'http://dbpedia.org/ontology/review',
#  'http://dbpedia.org/ontology/rkdArtistsId',
#  'http://dbpedia.org/ontology/role',
#  'http://dbpedia.org/ontology/routeEndDirection',
#  'http://dbpedia.org/ontology/routeNumber',
#  'http://dbpedia.org/ontology/routeStartDirection',
#  'http://dbpedia.org/ontology/routeTypeAbbreviation',
#  'http://dbpedia.org/ontology/runwayDesignation',
#  'http://dbpedia.org/ontology/runwaySurface',
#  'http://dbpedia.org/ontology/schoolCode',
#  'http://dbpedia.org/ontology/schoolNumber',
#  'http://dbpedia.org/ontology/selibrId',
#  'http://dbpedia.org/ontology/seniority',
#  'http://dbpedia.org/ontology/serviceNumber',
#  'http://dbpedia.org/ontology/servingTemperature',
#  'http://dbpedia.org/ontology/settingOfPlay',
#  'http://dbpedia.org/ontology/sex',
#  'http://dbpedia.org/ontology/shareSource',
#  'http://dbpedia.org/ontology/shoeSize',
#  'http://dbpedia.org/ontology/shoots',
#  'http://dbpedia.org/ontology/signature',
#  'http://dbpedia.org/ontology/sixthFormStudents',
#  'http://dbpedia.org/ontology/slogan',
#  'http://dbpedia.org/ontology/specialist',
#  'http://dbpedia.org/ontology/spike',
#  'http://dbpedia.org/ontology/stationStructure',
#  'http://dbpedia.org/ontology/status',
#  'http://dbpedia.org/ontology/strength',
#  'http://dbpedia.org/ontology/subjectOfPlay',
#  'http://dbpedia.org/ontology/subtitle',
#  'http://dbpedia.org/ontology/sudocId',
#  'http://dbpedia.org/ontology/supplementalDraftRound',
#  'http://dbpedia.org/ontology/symbol',
#  'http://dbpedia.org/ontology/synonym',
#  'http://dbpedia.org/ontology/teamName',
#  'http://dbpedia.org/ontology/tennisSurfaceType',
#  'http://dbpedia.org/ontology/throwingSide',
#  'http://dbpedia.org/ontology/time',
#  'http://dbpedia.org/ontology/timeshiftChannel',
#  'http://dbpedia.org/ontology/title',
#  'http://dbpedia.org/ontology/tournamentRecord',
#  'http://dbpedia.org/ontology/transmission',
#  'http://dbpedia.org/ontology/uciCode',
#  'http://dbpedia.org/ontology/ulanId',
#  'http://dbpedia.org/ontology/uniprot',
#  'http://dbpedia.org/ontology/unitedStatesNationalBridgeId',
#  'http://dbpedia.org/ontology/utcOffset',
#  'http://dbpedia.org/ontology/valvetrain',
#  'http://dbpedia.org/ontology/viafId',
#  'http://dbpedia.org/ontology/victims',
#  'http://dbpedia.org/ontology/virtualChannel',
#  'http://dbpedia.org/ontology/volumeQuote',
#  'http://dbpedia.org/ontology/whaDraft',
#  'http://dbpedia.org/ontology/widthQuote',
#  'http://dbpedia.org/ontology/worldChampionTitleYear',
#  'http://dbpedia.org/ontology/worstDefeat',
#  'http://purl.org/dc/elements/1.1/description',
#  'http://purl.org/dc/elements/1.1/publisher',
#  'http://purl.org/dc/elements/1.1/type',
#  'http://xmlns.com/foaf/0.1/familyName',
#  'http://xmlns.com/foaf/0.1/givenName',
#  'http://xmlns.com/foaf/0.1/name',
#  'http://xmlns.com/foaf/0.1/nick'}

# %%
relations_cnt.most_common()
# Out:
# [('http://xmlns.com/foaf/0.1/name', 3368646),
#  ('http://dbpedia.org/ontology/years', 927710),
#  ('http://dbpedia.org/ontology/numberOfGoals', 650801),
#  ('http://dbpedia.org/ontology/numberOfMatches', 645122),
#  ('http://dbpedia.org/ontology/birthDate', 630419),
#  ('http://dbpedia.org/ontology/utcOffset', 445717),
#  ('http://dbpedia.org/ontology/populationTotal', 327277),
#  ('http://dbpedia.org/ontology/runtime', 274334),
#  ('http://dbpedia.org/ontology/activeYearsStartYear', 254812),
#  ('http://dbpedia.org/ontology/synonym', 253511),
#  ('http://dbpedia.org/ontology/elevation', 247824),
#  ('http://dbpedia.org/ontology/title', 247497),
#  ('http://dbpedia.org/ontology/squadNumber', 245563),
#  ('http://dbpedia.org/ontology/releaseDate', 212290),
#  ('http://dbpedia.org/ontology/height', 202143),
#  ('http://dbpedia.org/ontology/deathDate', 197044),
#  ('http://dbpedia.org/ontology/postalCode', 188395),
#  ('http://dbpedia.org/ontology/areaTotal', 179581),
#  ('http://dbpedia.org/ontology/office', 177682),
#  ('http://dbpedia.org/ontology/birthYear', 160048),
#  ('http://dbpedia.org/ontology/activeYearsEndYear', 151754),
#  ('http://dbpedia.org/ontology/areaCode', 129943),
#  ('http://dbpedia.org/ontology/activeYearsStartDate', 103132),
#  ('http://dbpedia.org/ontology/foundingYear', 90919),
#  ('http://dbpedia.org/ontology/activeYearsEndDate', 84148),
#  ('http://dbpedia.org/ontology/background', 83193),
#  ('http://dbpedia.org/ontology/weight', 80374),
#  ('http://dbpedia.org/ontology/birthName', 79134),
#  ('http://dbpedia.org/ontology/length', 75987),
#  ('http://dbpedia.org/ontology/populationDensity', 75485),
#  ('http://dbpedia.org/ontology/deathYear', 74740),
#  ('http://dbpedia.org/ontology/areaLand', 72766),
#  ('http://dbpedia.org/ontology/imdbId', 72380),
#  ('http://dbpedia.org/ontology/number', 71000),
#  ('http://dbpedia.org/ontology/area', 70572),
#  ('http://dbpedia.org/ontology/leaderTitle', 66571),
#  ('http://dbpedia.org/ontology/address', 56143),
#  ('http://dbpedia.org/ontology/nrhpReferenceNumber', 55939),
#  ('http://dbpedia.org/ontology/areaWater', 55568),
#  ('http://dbpedia.org/ontology/alias', 55278),
#  ('http://dbpedia.org/ontology/added', 55268),
#  ('http://xmlns.com/foaf/0.1/nick', 52506),
#  ('http://dbpedia.org/ontology/yearOfConstruction', 49389),
#  ('http://dbpedia.org/ontology/conservationStatus', 48262),
#  ('http://dbpedia.org/ontology/status', 47976),
#  ('http://dbpedia.org/ontology/conservationStatusSystem', 47211),
#  ('http://dbpedia.org/ontology/orderInOffice', 46824),
#  ('http://dbpedia.org/ontology/openingYear', 43756),
#  ('http://dbpedia.org/ontology/motto', 42633),
#  ('http://dbpedia.org/ontology/year', 40047),
#  ('http://dbpedia.org/ontology/militaryCommand', 38957),
#  ('http://dbpedia.org/ontology/maximumElevation', 38564),
#  ('http://dbpedia.org/ontology/minimumElevation', 37766),
#  ('http://dbpedia.org/ontology/combatant', 37118),
#  ('http://dbpedia.org/ontology/inseeCode', 37081),
#  ('http://dbpedia.org/ontology/time', 36444),
#  ('http://dbpedia.org/ontology/strength', 34863),
#  ('http://xmlns.com/foaf/0.1/givenName', 32453),
#  ('http://purl.org/dc/elements/1.1/publisher', 31906),
#  ('http://dbpedia.org/ontology/numberOfEpisodes', 29969),
#  ('http://dbpedia.org/ontology/numberOfStudents', 29348),
#  ('http://dbpedia.org/ontology/shipBeam', 28794),
#  ('http://dbpedia.org/ontology/runwayLength', 27841),
#  ('http://dbpedia.org/ontology/numberOfPages', 26613),
#  ('http://dbpedia.org/ontology/serviceStartYear', 25896),
#  ('http://dbpedia.org/ontology/bSide', 24916),
#  ('http://dbpedia.org/ontology/isbn', 24777),
#  ('http://dbpedia.org/ontology/draftYear', 24521),
#  ('http://dbpedia.org/ontology/foundingDate', 23926),
#  ('http://dbpedia.org/ontology/gridReference', 23925),
#  ('http://dbpedia.org/ontology/completionDate', 22710),
#  ('http://dbpedia.org/ontology/numberOfEmployees', 21319),
#  ('http://dbpedia.org/ontology/allegiance', 21032),
#  ('http://dbpedia.org/ontology/serviceEndYear', 20857),
#  ('http://dbpedia.org/ontology/formationYear', 20623),
#  ('http://dbpedia.org/ontology/openingDate', 20352),
#  ('http://dbpedia.org/ontology/formerCallsign', 20279),
#  ('http://dbpedia.org/ontology/railwayPlatforms', 19933),
#  ('http://dbpedia.org/ontology/populationAsOf', 19866),
#  ('http://dbpedia.org/ontology/numberOfSeasons', 19367),
#  ('http://dbpedia.org/ontology/oclc', 19299),
#  ('http://dbpedia.org/ontology/routeNumber', 18716),
#  ('http://dbpedia.org/ontology/routeTypeAbbreviation', 18605),
#  ('http://dbpedia.org/ontology/budget', 18222),
#  ('http://dbpedia.org/ontology/topSpeed', 18114),
#  ('http://dbpedia.org/ontology/slogan', 18098),
#  ('http://dbpedia.org/ontology/shipLaunch', 18006),
#  ('http://dbpedia.org/ontology/gross', 17952),
#  ('http://dbpedia.org/ontology/causalties', 17906),
#  ('http://dbpedia.org/ontology/result', 17684),
#  ('http://dbpedia.org/ontology/runwayDesignation', 17642),
#  ('http://dbpedia.org/ontology/date', 17586),
#  ('http://dbpedia.org/ontology/broadcastStationClass', 17139),
#  ('http://dbpedia.org/ontology/buildingEndDate', 16636),
#  ('http://dbpedia.org/ontology/displacement', 16542),
#  ('http://dbpedia.org/ontology/formerName', 16479),
#  ('http://dbpedia.org/ontology/frequency', 16350),
#  ('http://dbpedia.org/ontology/recordDate', 16252),
#  ('http://dbpedia.org/ontology/routeStartDirection', 16226),
#  ('http://dbpedia.org/ontology/routeEndDirection', 16201),
#  ('http://dbpedia.org/ontology/facilityId', 15870),
#  ('http://dbpedia.org/ontology/capacity', 15227),
#  ('http://dbpedia.org/ontology/runwaySurface', 15003),
#  ('http://dbpedia.org/ontology/mascot', 14752),
#  ('http://dbpedia.org/ontology/firstAirDate', 14405),
#  ('http://dbpedia.org/ontology/commissioningDate', 14334),
#  ('http://dbpedia.org/ontology/shoots', 14315),
#  ('http://dbpedia.org/ontology/filename', 13413),
#  ('http://dbpedia.org/ontology/width', 13316),
#  ('http://dbpedia.org/ontology/description', 13291),
#  ('http://dbpedia.org/ontology/iupacName', 13265),
#  ('http://dbpedia.org/ontology/issn', 13247),
#  ('http://dbpedia.org/ontology/callsignMeaning', 13201),
#  ('http://dbpedia.org/ontology/heightAboveAverageTerrain', 13108),
#  ('http://dbpedia.org/ontology/numberOfTracks', 12112),
#  ('http://dbpedia.org/ontology/shipDraft', 12017),
#  ('http://dbpedia.org/ontology/layingDown', 11839),
#  ('http://dbpedia.org/ontology/icaoLocationIdentifier', 11702),
#  ('http://dbpedia.org/ontology/buildingStartDate', 11634),
#  ('http://dbpedia.org/ontology/numberBuilt', 11197),
#  ('http://dbpedia.org/ontology/officialSchoolColour', 11157),
#  ('http://dbpedia.org/ontology/draftPick', 10974),
#  ('http://dbpedia.org/ontology/transmission', 10932),
#  ('http://dbpedia.org/ontology/startDate', 10661),
#  ('http://dbpedia.org/ontology/draftRound', 10661),
#  ('http://dbpedia.org/ontology/abbreviation', 10464),
#  ('http://dbpedia.org/ontology/agencyStationCode', 10385),
#  ('http://dbpedia.org/ontology/personName', 10319),
#  ('http://dbpedia.org/ontology/percentageOfAreaWater', 10169),
#  ('http://dbpedia.org/ontology/productionStartYear', 10087),
#  ('http://dbpedia.org/ontology/draft', 10063),
#  ('http://dbpedia.org/ontology/facultySize', 10050),
#  ('http://dbpedia.org/ontology/configuration', 9911),
#  ('http://dbpedia.org/ontology/revenue', 9734),
#  ('http://dbpedia.org/ontology/formationDate', 9516),
#  ('http://dbpedia.org/ontology/licensee', 9403),
#  ('http://dbpedia.org/ontology/passengersPerYear', 9355),
#  ('http://dbpedia.org/ontology/role', 9160),
#  ('http://dbpedia.org/ontology/latestReleaseVersion', 8797),
#  ('http://dbpedia.org/ontology/colourName', 8796),
#  ('http://dbpedia.org/ontology/extinctionYear', 8521),
#  ('http://dbpedia.org/ontology/decommissioningDate', 8438),
#  ('http://dbpedia.org/ontology/episodeNumber', 8170),
#  ('http://dbpedia.org/ontology/productionEndYear', 8072),
#  ('http://dbpedia.org/ontology/iataLocationIdentifier', 7963),
#  ('http://dbpedia.org/ontology/stationStructure', 7926),
#  ('http://dbpedia.org/ontology/militaryUnitSize', 7887),
#  ('http://dbpedia.org/ontology/participant', 7807),
#  ('http://dbpedia.org/ontology/mouthElevation', 7664),
#  ('http://dbpedia.org/ontology/seasonNumber', 7599),
#  ('http://dbpedia.org/ontology/isoCodeRegion', 7511),
#  ('http://dbpedia.org/ontology/prominence', 7499),
#  ('http://dbpedia.org/ontology/teamName', 7463),
#  ('http://dbpedia.org/ontology/overallRecord', 7211),
#  ('http://dbpedia.org/ontology/lcc', 7123),
#  ('http://dbpedia.org/ontology/automobileModel', 6894),
#  ('http://dbpedia.org/ontology/iso6393Code', 6858),
#  ('http://dbpedia.org/ontology/startYearOfInsertion', 6690),
#  ('http://dbpedia.org/ontology/firstPublicationYear', 6668),
#  ('http://dbpedia.org/ontology/identificationSymbol', 6551),
#  ('http://dbpedia.org/ontology/numberSold', 6439),
#  ('http://dbpedia.org/ontology/managerTitle', 6395),
#  ('http://dbpedia.org/ontology/floorCount', 6375),
#  ('http://dbpedia.org/ontology/frequencyOfPublication', 6346),
#  ('http://dbpedia.org/ontology/purpose', 6176),
#  ('http://dbpedia.org/ontology/endYearOfInsertion', 5969),
#  ('http://dbpedia.org/ontology/powerOutput', 5919),
#  ('http://dbpedia.org/ontology/lowerAge', 5881),
#  ('http://dbpedia.org/ontology/upperAge', 5711),
#  ('http://dbpedia.org/ontology/shipDisplacement', 5647),
#  ('http://dbpedia.org/ontology/characterInPlay', 5600),
#  ('http://dbpedia.org/ontology/otherServingLines', 5564),
#  ('http://dbpedia.org/ontology/firstAppearance', 5562),
#  ('http://dbpedia.org/ontology/casNumber', 5548),
#  ('http://dbpedia.org/ontology/dcc', 5544),
#  ('http://dbpedia.org/ontology/parkingInformation', 5530),
#  ('http://dbpedia.org/ontology/wheelbase', 5442),
#  ('http://dbpedia.org/ontology/nationalTopographicSystemMapNumber', 5419),
#  ('http://dbpedia.org/ontology/chairmanTitle', 5383),
#  ('http://dbpedia.org/ontology/ecNumber', 5343),
#  ('http://dbpedia.org/ontology/acquirementDate', 5311),
#  ('http://dbpedia.org/ontology/undraftedYear', 5273),
#  ('http://dbpedia.org/ontology/games', 5253),
#  ('http://dbpedia.org/ontology/pubchem', 5212),
#  ('http://dbpedia.org/ontology/staff', 5205),
#  ('http://dbpedia.org/ontology/iucnCategory', 5164),
#  ('http://dbpedia.org/ontology/icd9', 5161),
#  ('http://dbpedia.org/ontology/circulation', 5081),
#  ('http://dbpedia.org/ontology/digitalChannel', 5064),
#  ('http://dbpedia.org/ontology/headLabel', 5015),
#  ('http://dbpedia.org/ontology/fareZone', 4761),
#  ('http://dbpedia.org/ontology/orderDate', 4725),
#  ('http://dbpedia.org/ontology/atcPrefix', 4699),
#  ('http://dbpedia.org/ontology/netIncome', 4674),
#  ('http://dbpedia.org/ontology/totalPopulation', 4645),
#  ('http://dbpedia.org/ontology/internationally', 4560),
#  ('http://dbpedia.org/ontology/sourceElevation', 4541),
#  ('http://dbpedia.org/ontology/isHandicappedAccessible', 4475),
#  ('http://dbpedia.org/ontology/numberOfVolumes', 4345),
#  ('http://dbpedia.org/ontology/fate', 4341),
#  ('http://dbpedia.org/ontology/cost', 4338),
#  ('http://dbpedia.org/ontology/symbol', 4271),
#  ('http://dbpedia.org/ontology/formerChannel', 4248),
#  ('http://dbpedia.org/ontology/effectiveRadiatedPower', 4246),
#  ('http://dbpedia.org/ontology/faaLocationIdentifier', 4222),
#  ('http://dbpedia.org/ontology/ingredientName', 4217),
#  ('http://dbpedia.org/ontology/membership', 4155),
#  ('http://dbpedia.org/ontology/icd10', 4134),
#  ('http://dbpedia.org/ontology/censusYear', 4089),
#  ('http://dbpedia.org/ontology/closingYear', 4084),
#  ('http://dbpedia.org/ontology/volume', 4082),
#  ('http://dbpedia.org/ontology/maximumDepth', 4069),
#  ('http://dbpedia.org/ontology/sex', 4036),
#  ('http://dbpedia.org/ontology/floorArea', 3985),
#  ('http://dbpedia.org/ontology/numberOfUndergraduateStudents', 3981),
#  ('http://dbpedia.org/ontology/plays', 3973),
#  ('http://www.w3.org/2003/01/geo/wgs84_pos#long', 3970),
#  ('http://www.w3.org/2003/01/geo/wgs84_pos#lat', 3968),
#  ('http://dbpedia.org/ontology/fdaUniiCode', 3925),
#  ('http://dbpedia.org/ontology/certification', 3853),
#  ('http://dbpedia.org/ontology/impactFactor', 3774),
#  ('http://dbpedia.org/ontology/visitorStatisticsAsOf', 3771),
#  ('http://dbpedia.org/ontology/impactFactorAsOf', 3751),
#  ('http://dbpedia.org/ontology/callSign', 3742),
#  ('http://dbpedia.org/ontology/assets', 3682),
#  ('http://dbpedia.org/ontology/careerPrizeMoney', 3667),
#  ('http://dbpedia.org/ontology/digitalSubChannel', 3642),
#  ('http://dbpedia.org/ontology/publicationDate', 3603),
#  ('http://dbpedia.org/ontology/absoluteMagnitude', 3565),
#  ('http://dbpedia.org/ontology/meaning', 3479),
#  ('http://dbpedia.org/ontology/icaoAirlineCode', 3390),
#  ('http://dbpedia.org/ontology/pseudonym', 3364),
#  ('http://dbpedia.org/ontology/distanceToLondon', 3333),
#  ('http://dbpedia.org/ontology/numberOfLocations', 3309),
#  ('http://dbpedia.org/ontology/hairColor', 3302),
#  ('http://dbpedia.org/ontology/bridgeCarries', 3275),
#  ('http://dbpedia.org/ontology/iataAirlineCode', 3262),
#  ('http://dbpedia.org/ontology/numberOfStations', 3255),
#  ('http://dbpedia.org/ontology/orbitalPeriod', 3244),
#  ('http://dbpedia.org/ontology/populationUrban', 3231),
#  ('http://dbpedia.org/ontology/numberOfPostgraduateStudents', 3231),
#  ('http://dbpedia.org/ontology/lineLength', 3228),
#  ('http://dbpedia.org/ontology/discovered', 3203),
#  ('http://dbpedia.org/ontology/epoch', 3166),
#  ('http://dbpedia.org/ontology/eyeColor', 3164),
#  ('http://dbpedia.org/ontology/apoapsis', 3140),
#  ('http://dbpedia.org/ontology/periapsis', 3126),
#  ('http://dbpedia.org/ontology/lccn', 3108),
#  ('http://dbpedia.org/ontology/torqueOutput', 3074),
#  ('http://dbpedia.org/ontology/seatingCapacity', 3046),
#  ('http://dbpedia.org/ontology/operatingIncome', 3008),
#  ('http://dbpedia.org/ontology/populationTotalRanking', 2983),
#  ('http://dbpedia.org/ontology/aSide', 2979),
#  ('http://dbpedia.org/ontology/battleHonours', 2959),
#  ('http://dbpedia.org/ontology/dissolutionYear', 2872),
#  ('http://dbpedia.org/ontology/grayPage', 2795),
#  ('http://dbpedia.org/ontology/graySubject', 2789),
#  ('http://dbpedia.org/ontology/municipalityCode', 2767),
#  ('http://dbpedia.org/ontology/meshId', 2719),
#  ('http://dbpedia.org/ontology/depictionDescription', 2710),
#  ('http://dbpedia.org/ontology/trackNumber', 2710),
#  ('http://dbpedia.org/ontology/course', 2704),
#  ('http://dbpedia.org/ontology/installedCapacity', 2702),
#  ('http://dbpedia.org/ontology/omim', 2700),
#  ('http://dbpedia.org/ontology/atcSuffix', 2700),
#  ('http://dbpedia.org/ontology/distance', 2670),
#  ('http://dbpedia.org/ontology/bicycleInformation', 2637),
#  ('http://purl.org/dc/elements/1.1/type', 2636),
#  ('http://dbpedia.org/ontology/averageDepth', 2500),
#  ('http://dbpedia.org/ontology/established', 2493),
#  ('http://dbpedia.org/ontology/dorlandsSuffix', 2389),
#  ('http://dbpedia.org/ontology/dorlandsPrefix', 2386),
#  ('http://dbpedia.org/ontology/buildingStartYear', 2337),
#  ('http://dbpedia.org/ontology/rebuildingYear', 2330),
#  ('http://dbpedia.org/ontology/note', 2184),
#  ('http://dbpedia.org/ontology/extinctionDate', 2183),
#  ('http://dbpedia.org/ontology/firstPublicationDate', 2165),
#  ('http://dbpedia.org/ontology/rotationPeriod', 2146),
#  ('http://dbpedia.org/ontology/latestReleaseDate', 2145),
#  ('http://dbpedia.org/ontology/equity', 2143),
#  ('http://dbpedia.org/ontology/coden', 2115),
#  ('http://dbpedia.org/ontology/networth', 2090),
#  ('http://dbpedia.org/ontology/watershed', 2075),
#  ('http://dbpedia.org/ontology/electionMajority', 2055),
#  ('http://dbpedia.org/ontology/bedCount', 2026),
#  ('http://dbpedia.org/ontology/firstAscentYear', 2025),
#  ('http://dbpedia.org/ontology/populationMetro', 1949),
#  ('http://dbpedia.org/ontology/endowment', 1935),
#  ('http://dbpedia.org/ontology/editorTitle', 1932),
#  ('http://dbpedia.org/ontology/signature', 1912),
#  ('http://dbpedia.org/ontology/cosparId', 1908),
#  ('http://dbpedia.org/ontology/currentSeason', 1894),
#  ('http://dbpedia.org/ontology/closingDate', 1887),
#  ('http://dbpedia.org/ontology/campusType', 1877),
#  ('http://dbpedia.org/ontology/longtype', 1823),
#  ('http://dbpedia.org/ontology/numberOfMembers', 1767),
#  ('http://dbpedia.org/ontology/unitCost', 1755),
#  ('http://dbpedia.org/ontology/shoreLength', 1740),
#  ('http://dbpedia.org/ontology/otherName', 1719),
#  ('http://dbpedia.org/ontology/mainspan', 1684),
#  ('http://dbpedia.org/ontology/imageSize', 1675),
#  ('http://dbpedia.org/ontology/drugbank', 1637),
#  ('http://dbpedia.org/ontology/premiereYear', 1626),
#  ('http://dbpedia.org/ontology/yearOfElectrification', 1626),
#  ('http://dbpedia.org/ontology/broadcastTranslator', 1615),
#  ('http://dbpedia.org/ontology/isPartOfName', 1614),
#  ('http://dbpedia.org/ontology/numberOfTeams', 1604),
#  ('http://dbpedia.org/ontology/viafId', 1599),
#  ('http://dbpedia.org/ontology/shareOfAudience', 1569),
#  ('http://dbpedia.org/ontology/code', 1564),
#  ('http://dbpedia.org/ontology/speedLimit', 1551),
#  ('http://dbpedia.org/ontology/carNumber', 1545),
#  ('http://dbpedia.org/ontology/modelStartYear', 1537),
#  ('http://dbpedia.org/ontology/numberOfVisitors', 1532),
#  ('http://dbpedia.org/ontology/entrezgene', 1509),
#  ('http://dbpedia.org/ontology/usSales', 1394),
#  ('http://dbpedia.org/ontology/albedo', 1386),
#  ('http://dbpedia.org/ontology/canBaggageChecked', 1356),
#  ('http://dbpedia.org/ontology/distanceLaps', 1356),
#  ('http://dbpedia.org/ontology/discharge', 1354),
#  ('http://dbpedia.org/ontology/chEBI', 1338),
#  ('http://dbpedia.org/ontology/hgncid', 1332),
#  ('http://dbpedia.org/ontology/diameter', 1325),
#  ('http://dbpedia.org/ontology/logo', 1317),
#  ('http://dbpedia.org/ontology/refseq', 1314),
#  ('http://dbpedia.org/ontology/uniprot', 1309),
#  ('http://dbpedia.org/ontology/foalDate', 1297),
#  ('http://dbpedia.org/ontology/settingOfPlay', 1235),
#  ('http://dbpedia.org/ontology/name', 1228),
#  ('http://dbpedia.org/ontology/modelEndYear', 1225),
#  ('http://dbpedia.org/ontology/numberOfPlatformLevels', 1221),
#  ('http://dbpedia.org/ontology/chromosome', 1212),
#  ('http://dbpedia.org/ontology/areaOfCatchment', 1211),
#  ('http://dbpedia.org/ontology/lastPublicationDate', 1204),
#  ('http://dbpedia.org/ontology/averageClassSize', 1198),
#  ('http://dbpedia.org/ontology/wins', 1190),
#  ('http://dbpedia.org/ontology/band', 1180),
#  ('http://dbpedia.org/ontology/ceeb', 1179),
#  ('http://dbpedia.org/ontology/openAccessContent', 1148),
#  ('http://dbpedia.org/ontology/shareSource', 1139),
#  ('http://dbpedia.org/ontology/colourHexCode', 1105),
#  ('http://dbpedia.org/ontology/rgbCoordinateGreen', 1085),
#  ('http://dbpedia.org/ontology/campusSize', 1084),
#  ('http://dbpedia.org/ontology/rgbCoordinateBlue', 1082),
#  ('http://dbpedia.org/ontology/rgbCoordinateRed', 1075),
#  ('http://dbpedia.org/ontology/frequentlyUpdated', 1070),
#  ('http://dbpedia.org/ontology/premiereDate', 1055),
#  ('http://dbpedia.org/ontology/dissolutionDate', 1050),
#  ('http://dbpedia.org/ontology/hsvCoordinateValue', 1043),
#  ('http://dbpedia.org/ontology/hsvCoordinateSaturation', 1043),
#  ('http://dbpedia.org/ontology/tuition', 1039),
#  ('http://dbpedia.org/ontology/visitorsPercentageChange', 1028),
#  ('http://dbpedia.org/ontology/hsvCoordinateHue', 1026),
#  ('http://dbpedia.org/ontology/numberOfRooms', 1010),
#  ('http://dbpedia.org/ontology/arm', 1000),
#  ('http://dbpedia.org/ontology/maximumDischarge', 995),
#  ('http://dbpedia.org/ontology/lastAirDate', 985),
#  ('http://dbpedia.org/ontology/analogChannel', 972),
#  ('http://dbpedia.org/ontology/currentRecord', 963),
#  ('http://dbpedia.org/ontology/interest', 956),
#  ('http://dbpedia.org/ontology/tournamentRecord', 952),
#  ('http://dbpedia.org/ontology/id', 937),
#  ('http://dbpedia.org/ontology/recommissioningDate', 936),
#  ('http://dbpedia.org/ontology/minimumDischarge', 934),
#  ('http://dbpedia.org/ontology/tennisSurfaceType', 933),
#  ('http://dbpedia.org/ontology/numberOfLines', 919),
#  ('http://dbpedia.org/ontology/cmykCoordinateBlack', 912),
#  ('http://dbpedia.org/ontology/cmykCoordinateMagenta', 911),
#  ('http://dbpedia.org/ontology/numberOfCompetitors', 898),
#  ('http://dbpedia.org/ontology/lastElectionDate', 897),
#  ('http://dbpedia.org/ontology/beatifiedDate', 896),
#  ('http://dbpedia.org/ontology/cmykCoordinateYellow', 895),
#  ('http://dbpedia.org/ontology/generationUnits', 884),
#  ('http://dbpedia.org/ontology/broadcastRepeater', 868),
#  ('http://dbpedia.org/ontology/committee', 837),
#  ('http://dbpedia.org/ontology/numberOfFilms', 836),
#  ('http://dbpedia.org/ontology/eruptionYear', 835),
#  ('http://dbpedia.org/ontology/otherChannel', 832),
#  ('http://dbpedia.org/ontology/ageRange', 830),
#  ('http://dbpedia.org/ontology/cmykCoordinateCyanic', 828),
#  ('http://dbpedia.org/ontology/fileSize', 827),
#  ('http://dbpedia.org/ontology/casualties', 826),
#  ('http://dbpedia.org/ontology/averageAnnualGeneration', 820),
#  ('http://dbpedia.org/ontology/cuisine', 817),
#  ('http://dbpedia.org/ontology/debut', 816),
#  ('http://dbpedia.org/ontology/serviceNumber', 811),
#  ('http://dbpedia.org/ontology/servingTemperature', 808),
#  ('http://dbpedia.org/ontology/maidenVoyage', 802),
#  ('http://dbpedia.org/ontology/numberOfStaff', 796),
#  ('http://dbpedia.org/ontology/trackLength', 792),
#  ('http://dbpedia.org/ontology/areaUrban', 779),
#  ('http://dbpedia.org/ontology/areaMetro', 779),
#  ('http://dbpedia.org/ontology/championships', 777),
#  ('http://dbpedia.org/ontology/numberOfSpans', 774),
#  ('http://dbpedia.org/ontology/numberOfIslands', 767),
#  ('http://dbpedia.org/ontology/races', 763),
#  ('http://dbpedia.org/ontology/notes', 756),
#  ('http://dbpedia.org/ontology/podiums', 755),
#  ('http://dbpedia.org/ontology/fastestLap', 753),
#  ('http://dbpedia.org/ontology/poles', 752),
#  ('http://dbpedia.org/ontology/cylinderCount', 746),
#  ('http://dbpedia.org/ontology/voltageOfElectrification', 740),
#  ('http://dbpedia.org/ontology/averageSpeed', 735),
#  ('http://dbpedia.org/ontology/currentStatus', 731),
#  ('http://dbpedia.org/ontology/seniority', 729),
#  ('http://dbpedia.org/ontology/numberOfSports', 723),
#  ('http://dbpedia.org/ontology/oversight', 722),
#  ('http://dbpedia.org/ontology/specialist', 721),
#  ('http://dbpedia.org/ontology/passengersPerDay', 719),
#  ('http://dbpedia.org/ontology/demonym', 685),
#  ('http://dbpedia.org/ontology/latestPreviewVersion', 682),
#  ('http://dbpedia.org/ontology/bowlRecord', 672),
#  ('http://dbpedia.org/ontology/captureDate', 666),
#  ('http://dbpedia.org/ontology/battingSide', 664),
#  ('http://dbpedia.org/ontology/bioavailability', 663),
#  ('http://dbpedia.org/ontology/acceleration', 661),
#  ('http://dbpedia.org/ontology/throwingSide', 658),
#  ('http://dbpedia.org/ontology/depth', 649),
#  ('http://dbpedia.org/ontology/distanceToCardiff', 644),
#  ('http://dbpedia.org/ontology/numberOfBronzeMedalsWon', 644),
#  ('http://dbpedia.org/ontology/numberOfGoldMedalsWon', 641),
#  ('http://dbpedia.org/ontology/numberOfSilverMedalsWon', 641),
#  ('http://dbpedia.org/ontology/quote', 635),
#  ('http://dbpedia.org/ontology/subjectOfPlay', 614),
#  ('http://dbpedia.org/ontology/meshName', 607),
#  ('http://dbpedia.org/ontology/rankInFinalMedalCount', 606),
#  ('http://dbpedia.org/ontology/legislativePeriodName', 604),
#  ('http://dbpedia.org/ontology/vehiclesPerDay', 601),
#  ('http://dbpedia.org/ontology/material', 576),
#  ('http://dbpedia.org/ontology/schoolNumber', 572),
#  ('http://dbpedia.org/ontology/numberOfDoctoralStudents', 571),
#  ('http://dbpedia.org/ontology/electionDateLeader', 567),
#  ('http://dbpedia.org/ontology/meshNumber', 556),
#  ('http://dbpedia.org/ontology/finalPublicationYear', 555),
#  ('http://dbpedia.org/ontology/neighbourConstellations', 550),
#  ('http://dbpedia.org/ontology/shareDate', 547),
#  ('http://dbpedia.org/ontology/offeredClasses', 538),
#  ('http://dbpedia.org/ontology/cityType', 530),
#  ('http://dbpedia.org/ontology/numberOfRestaurants', 528),
#  ('http://dbpedia.org/ontology/compressionRatio', 525),
#  ('http://dbpedia.org/ontology/endDate', 518),
#  ('http://dbpedia.org/ontology/valvetrain', 491),
#  ('http://dbpedia.org/ontology/cylinderBore', 489),
#  ('http://dbpedia.org/ontology/canonizedDate', 488),
#  ('http://dbpedia.org/ontology/publiclyAccessible', 478),
#  ('http://dbpedia.org/ontology/longName', 476),
#  ('http://dbpedia.org/ontology/jstor', 468),
#  ('http://dbpedia.org/ontology/pistonStroke', 466),
#  ('http://dbpedia.org/ontology/fuelType', 464),
#  ('http://dbpedia.org/ontology/highestRank', 462),
#  ('http://dbpedia.org/ontology/lccnId', 457),
#  ('http://dbpedia.org/ontology/frozen', 452),
#  ('http://dbpedia.org/ontology/christeningDate', 441),
#  ('http://dbpedia.org/ontology/numberOfSuites', 432),
#  ('http://dbpedia.org/ontology/disbanded', 431),
#  ('http://dbpedia.org/ontology/numberOfVehicles', 424),
#  ('http://dbpedia.org/ontology/numberOfOffices', 423),
#  ('http://dbpedia.org/ontology/rebuildingDate', 423),
#  ('http://dbpedia.org/ontology/numberOfLawyers', 421),
#  ('http://dbpedia.org/ontology/highestBreak', 415),
#  ('http://dbpedia.org/ontology/unitedStatesNationalBridgeId', 412),
#  ('http://dbpedia.org/ontology/flag', 411),
#  ('http://dbpedia.org/ontology/iso6392Code', 409),
#  ('http://dbpedia.org/ontology/mass', 409),
#  ('http://dbpedia.org/ontology/geology', 406),
#  ('http://dbpedia.org/ontology/salary', 406),
#  ('http://dbpedia.org/ontology/temperature', 405),
#  ('http://dbpedia.org/ontology/numberOfVolunteers', 401),
#  ('http://dbpedia.org/ontology/classes', 400),
#  ('http://dbpedia.org/ontology/virtualChannel', 397),
#  ('http://dbpedia.org/ontology/waistSize', 394),
#  ('http://dbpedia.org/ontology/access', 387),
#  ('http://dbpedia.org/ontology/uciCode', 387),
#  ('http://dbpedia.org/ontology/hipSize', 384),
#  ('http://dbpedia.org/ontology/collection', 382),
#  ('http://dbpedia.org/ontology/shoeSize', 376),
#  ('http://dbpedia.org/ontology/schoolCode', 376),
#  ('http://dbpedia.org/ontology/brainInfoNumber', 374),
#  ('http://purl.org/dc/elements/1.1/description', 373),
#  ('http://dbpedia.org/ontology/brainInfoType', 372),
#  ('http://dbpedia.org/ontology/centuryBreaks', 365),
#  ('http://dbpedia.org/ontology/totalLaunches', 362),
#  ('http://dbpedia.org/ontology/whaDraft', 359),
#  ('http://dbpedia.org/ontology/lowest', 358),
#  ('http://dbpedia.org/ontology/portfolio', 343),
#  ('http://dbpedia.org/ontology/bestFinish', 343),
#  ('http://dbpedia.org/ontology/activeYears', 328),
#  ('http://dbpedia.org/ontology/bustSize', 316),
#  ('http://dbpedia.org/ontology/casSupplemental', 309),
#  ('http://dbpedia.org/ontology/locusSupplementaryData', 308),
#  ('http://dbpedia.org/ontology/passengersUsedSystem', 300),
#  ('http://dbpedia.org/ontology/hallOfFame', 298),
#  ('http://dbpedia.org/ontology/escapeVelocity', 298),
#  ('http://dbpedia.org/ontology/production', 293),
#  ('http://dbpedia.org/ontology/populationRural', 282),
#  ('http://dbpedia.org/ontology/timeshiftChannel', 276),
#  ('http://dbpedia.org/ontology/maidenFlight', 272),
#  ('http://dbpedia.org/ontology/successfulLaunches', 267),
#  ('http://dbpedia.org/ontology/subtitle', 248),
#  ('http://dbpedia.org/ontology/populationMetroDensity', 247),
#  ('http://dbpedia.org/ontology/numberOfLanes', 246),
#  ('http://dbpedia.org/ontology/toll', 242),
#  ('http://dbpedia.org/ontology/individualisedGnd', 229),
#  ('http://dbpedia.org/ontology/model', 226),
#  ('http://dbpedia.org/ontology/numberOfPiersInWater', 225),
#  ('http://dbpedia.org/ontology/rating', 224),
#  ('http://dbpedia.org/ontology/apparentMagnitude', 222),
#  ('http://dbpedia.org/ontology/dressCode', 209),
#  ('http://dbpedia.org/ontology/sourceConfluenceElevation', 208),
#  ('http://dbpedia.org/ontology/ranking', 207),
#  ('http://dbpedia.org/ontology/reportingMark', 206),
#  ('http://dbpedia.org/ontology/icdo', 205),
#  ('http://dbpedia.org/ontology/rocketStages', 203),
#  ('http://dbpedia.org/ontology/anniversary', 203),
#  ('http://dbpedia.org/ontology/failedLaunches', 200),
#  ('http://dbpedia.org/ontology/assetUnderManagement', 200),
#  ('http://dbpedia.org/ontology/dateOfAbandonment', 200),
#  ('http://dbpedia.org/ontology/other', 199),
#  ('http://dbpedia.org/ontology/iso6391Code', 197),
#  ('http://dbpedia.org/ontology/finalFlight', 195),
#  ('http://dbpedia.org/ontology/startYearOfSales', 194),
#  ('http://dbpedia.org/ontology/spike', 187),
#  ('http://dbpedia.org/ontology/retired', 182),
#  ('http://dbpedia.org/ontology/espnId', 179),
#  ('http://dbpedia.org/ontology/populationUrbanDensity', 178),
#  ('http://dbpedia.org/ontology/block', 173),
#  ('http://dbpedia.org/ontology/fees', 172),
#  ('http://dbpedia.org/ontology/distanceToCharingCross', 167),
#  ('http://dbpedia.org/ontology/dischargeAverage', 160),
#  ('http://dbpedia.org/ontology/endYearOfSales', 148),
#  ('http://dbpedia.org/ontology/otherWins', 147),
#  ('http://dbpedia.org/ontology/currentlyUsedFor', 147),
#  ('http://dbpedia.org/ontology/numberOfGraduateStudents', 146),
#  ('http://dbpedia.org/ontology/barPassRate', 143),
#  ('http://dbpedia.org/ontology/distanceToEdinburgh', 141),
#  ('http://dbpedia.org/ontology/dissolved', 135),
#  ('http://dbpedia.org/ontology/numberOfWineries', 134),
#  ('http://dbpedia.org/ontology/demolitionDate', 133),
#  ('http://dbpedia.org/ontology/visitorsPerYear', 132),
#  ('http://dbpedia.org/ontology/reopeningYear', 129),
#  ('http://dbpedia.org/ontology/meanRadius', 123),
#  ('http://dbpedia.org/ontology/density', 123),
#  ('http://dbpedia.org/ontology/worldChampionTitleYear', 121),
#  ('http://dbpedia.org/ontology/ethnicGroupsInYear', 120),
#  ('http://dbpedia.org/ontology/timeInSpace', 120),
#  ('http://dbpedia.org/ontology/railGauge', 119),
#  ('http://dbpedia.org/ontology/electionDate', 115),
#  ('http://dbpedia.org/ontology/coachingRecord', 110),
#  ('http://dbpedia.org/ontology/pdb', 109),
#  ('http://dbpedia.org/ontology/distanceToBelfast', 106),
#  ('http://dbpedia.org/ontology/atcSupplemental', 104),
#  ('http://dbpedia.org/ontology/numberOfVisitorsAsOf', 102),
#  ('http://dbpedia.org/ontology/geologicPeriod', 99),
#  ('http://dbpedia.org/ontology/bnfId', 97),
#  ('http://dbpedia.org/ontology/latestPreviewDate', 95),
#  ('http://dbpedia.org/ontology/victims', 95),
#  ('http://dbpedia.org/ontology/teamSize', 93),
#  ('http://dbpedia.org/ontology/month', 88),
#  ('http://dbpedia.org/ontology/governmentElevation', 83),
#  ('http://dbpedia.org/ontology/capacityFactor', 83),
#  ('http://dbpedia.org/ontology/maximumBoatBeam', 80),
#  ('http://dbpedia.org/ontology/programCost', 79),
#  ('http://dbpedia.org/ontology/servingSize', 78),
#  ('http://dbpedia.org/ontology/maximumBoatLength', 78),
#  ('http://dbpedia.org/ontology/numberOfParticipatingAthletes', 78),
#  ('http://dbpedia.org/ontology/demolitionYear', 77),
#  ('http://dbpedia.org/ontology/partialFailedLaunches', 76),
#  ('http://dbpedia.org/ontology/testaverage', 71),
#  ('http://dbpedia.org/ontology/largestWin', 69),
#  ('http://dbpedia.org/ontology/closed', 67),
#  ('http://dbpedia.org/ontology/reservations', 66),
#  ('http://dbpedia.org/ontology/declination', 63),
#  ('http://dbpedia.org/ontology/buildingEndYear', 63),
#  ('http://dbpedia.org/ontology/numberOfVineyards', 62),
#  ('http://dbpedia.org/ontology/worstDefeat', 62),
#  ('http://dbpedia.org/ontology/chorusCharacterInPlay', 61),
#  ('http://dbpedia.org/ontology/firstGame', 60),
#  ('http://dbpedia.org/ontology/supplementalDraftRound', 59),
#  ('http://dbpedia.org/ontology/sudocId', 58),
#  ('http://dbpedia.org/ontology/rankingWins', 58),
#  ('http://dbpedia.org/ontology/meanTemperature', 57),
#  ('http://dbpedia.org/ontology/duration', 57),
#  ('http://dbpedia.org/ontology/supplementalDraftYear', 57),
#  ('http://dbpedia.org/ontology/numberOfParkingSpaces', 56),
#  ('http://dbpedia.org/ontology/muteCharacterInPlay', 54),
#  ('http://dbpedia.org/ontology/numberOfPads', 54),
#  ('http://dbpedia.org/ontology/numberOfDeaths', 53),
#  ('http://dbpedia.org/ontology/lowerEarthOrbitPayload', 51),
#  ('http://dbpedia.org/ontology/numberOfParticipatingNations', 51),
#  ('http://dbpedia.org/ontology/isniId', 50),
#  ('http://dbpedia.org/ontology/orbitalFlights', 49),
#  ('http://dbpedia.org/ontology/totalTravellers', 49),
#  ('http://dbpedia.org/ontology/statisticValue', 49),
#  ('http://dbpedia.org/ontology/maximumTemperature', 47),
#  ('http://dbpedia.org/ontology/capitalElevation', 46),
#  ('http://dbpedia.org/ontology/speaker', 46),
#  ('http://dbpedia.org/ontology/introductionDate', 45),
#  ('http://dbpedia.org/ontology/minimumTemperature', 42),
#  ('http://dbpedia.org/ontology/destructionDate', 42),
#  ('http://dbpedia.org/ontology/mapCaption', 41),
#  ('http://dbpedia.org/ontology/crownDependency', 41),
#  ('http://dbpedia.org/ontology/surfaceArea', 40),
#  ('http://dbpedia.org/ontology/productionStartDate', 40),
#  ('http://dbpedia.org/ontology/originallyUsedFor', 38),
#  ('http://dbpedia.org/ontology/liberationDate', 36),
#  ('http://dbpedia.org/ontology/certificationDate', 36),
#  ('http://dbpedia.org/ontology/deliveryDate', 34),
#  ('http://dbpedia.org/ontology/alternativeName', 31),
#  ('http://dbpedia.org/ontology/day', 31),
#  ('http://dbpedia.org/ontology/loadLimit', 31),
#  ('http://dbpedia.org/ontology/locationIdentifier', 31),
#  ('http://dbpedia.org/ontology/fansgroup', 31),
#  ('http://dbpedia.org/ontology/feastDay', 28),
#  ('http://dbpedia.org/ontology/nlaId', 27),
#  ('http://dbpedia.org/ontology/shoeNumber', 25),
#  ('http://dbpedia.org/ontology/ndlId', 23),
#  ('http://dbpedia.org/ontology/reopeningDate', 23),
#  ('http://dbpedia.org/ontology/review', 23),
#  ('http://dbpedia.org/ontology/detectionMethod', 23),
#  ('http://dbpedia.org/ontology/grossDomesticProduct', 20),
#  ('http://dbpedia.org/ontology/nutsCode', 20),
#  ('http://dbpedia.org/ontology/lastPosition', 20),
#  ('http://dbpedia.org/ontology/firstLaunchDate', 20),
#  ('http://dbpedia.org/ontology/lastLaunchDate', 20),
#  ('http://xmlns.com/foaf/0.1/familyName', 20),
#  ('http://dbpedia.org/ontology/areaRural', 19),
#  ('http://dbpedia.org/ontology/mbaId', 19),
#  ('http://dbpedia.org/ontology/managementElevation', 17),
#  ('http://dbpedia.org/ontology/launches', 17),
#  ('http://dbpedia.org/ontology/floodingDate', 16),
#  ('http://dbpedia.org/ontology/dateUse', 15),
#  ('http://dbpedia.org/ontology/introduced', 15),
#  ('http://dbpedia.org/ontology/productionEndDate', 15),
#  ('http://dbpedia.org/ontology/sixthFormStudents', 15),
#  ('http://dbpedia.org/ontology/wavelength', 14),
#  ('http://dbpedia.org/ontology/restoreDate', 14),
#  ('http://dbpedia.org/ontology/oldcode', 14),
#  ('http://dbpedia.org/ontology/dateCompleted', 12),
#  ('http://dbpedia.org/ontology/argueDate', 12),
#  ('http://dbpedia.org/ontology/dateConstruction', 11),
#  ('http://dbpedia.org/ontology/dateOfBurial', 11),
#  ('http://dbpedia.org/ontology/fuelCapacity', 11),
#  ('http://dbpedia.org/ontology/ulanId', 11),
#  ('http://dbpedia.org/ontology/nationalRanking', 11),
#  ('http://dbpedia.org/ontology/projectKeyword', 10),
#  ('http://dbpedia.org/ontology/missions', 9),
#  ('http://dbpedia.org/ontology/gasChambers', 9),
#  ('http://dbpedia.org/ontology/lastFlightStartDate', 8),
#  ('http://dbpedia.org/ontology/lastFlightEndDate', 8),
#  ('http://dbpedia.org/ontology/nssdcId', 8),
#  ('http://dbpedia.org/ontology/distanceToDouglas', 8),
#  ('http://dbpedia.org/ontology/approximateCalories', 8),
#  ('http://dbpedia.org/ontology/commonName', 8),
#  ('http://dbpedia.org/ontology/projectBudgetTotal', 8),
#  ('http://dbpedia.org/ontology/contractAward', 7),
#  ('http://dbpedia.org/ontology/firstFlightStartDate', 7),
#  ('http://dbpedia.org/ontology/firstFlightEndDate', 7),
#  ('http://dbpedia.org/ontology/originalMaximumBoatBeam', 7),
#  ('http://dbpedia.org/ontology/currentRank', 7),
#  ('http://dbpedia.org/ontology/orbits', 6),
#  ('http://dbpedia.org/ontology/crews', 6),
#  ('http://dbpedia.org/ontology/subdivisions', 5),
#  ('http://dbpedia.org/ontology/satellitesDeployed', 5),
#  ('http://dbpedia.org/ontology/selibrId', 5),
#  ('http://dbpedia.org/ontology/originalMaximumBoatLength', 5),
#  ('http://dbpedia.org/ontology/distanceToDublin', 5),
#  ('http://dbpedia.org/ontology/decideDate', 5),
#  ('http://dbpedia.org/ontology/dateAct', 4),
#  ('http://dbpedia.org/ontology/suborbitalFlights', 4),
#  ('http://dbpedia.org/ontology/projectBudgetFunding', 4),
#  ('http://dbpedia.org/ontology/glycemicIndex', 4),
#  ('http://dbpedia.org/ontology/ensembl', 4),
#  ('http://dbpedia.org/ontology/refseqmrna', 4),
#  ('http://dbpedia.org/ontology/refseqprotein', 4),
#  ('http://dbpedia.org/ontology/genomeDB', 4),
#  ('http://dbpedia.org/ontology/onChromosome', 4),
#  ('http://dbpedia.org/ontology/geneLocationStart', 4),
#  ('http://dbpedia.org/ontology/geneLocationEnd', 4),
#  ('http://dbpedia.org/ontology/co2Emission', 4),
#  ('http://dbpedia.org/ontology/mirDockings', 3),
#  ('http://dbpedia.org/ontology/issDockings', 3),
#  ('http://dbpedia.org/ontology/complexity', 3),
#  ('http://dbpedia.org/ontology/protein', 3),
#  ('http://dbpedia.org/ontology/bibsysId', 3),
#  ('http://dbpedia.org/ontology/minTime', 3),
#  ('http://dbpedia.org/ontology/maxTime', 3),
#  ('http://dbpedia.org/ontology/widthQuote', 2),
#  ('http://dbpedia.org/ontology/rebuildDate', 2),
#  ('http://dbpedia.org/ontology/elevationQuote', 2),
#  ('http://dbpedia.org/ontology/carbohydrate', 2),
#  ('http://dbpedia.org/ontology/fat', 2),
#  ('http://dbpedia.org/ontology/fuelConsumption', 2),
#  ('http://dbpedia.org/ontology/isPeerReviewed', 2),
#  ('http://dbpedia.org/ontology/numberOfOfficials', 2),
#  ('http://dbpedia.org/ontology/lengthReference', 2),
#  ('http://dbpedia.org/ontology/projectStartDate', 2),
#  ('http://dbpedia.org/ontology/projectEndDate', 2),
#  ('http://dbpedia.org/ontology/nameDay', 2),
#  ('http://dbpedia.org/ontology/statisticYear', 2),
#  ('http://dbpedia.org/ontology/areaQuote', 1),
#  ('http://dbpedia.org/ontology/averageDepthQuote', 1),
#  ('http://dbpedia.org/ontology/maximumDepthQuote', 1),
#  ('http://dbpedia.org/ontology/volumeQuote', 1),
#  ('http://dbpedia.org/ontology/suppreddedDate', 1),
#  ('http://dbpedia.org/ontology/ibdbId', 1),
#  ('http://dbpedia.org/ontology/bpnId', 1),
#  ('http://dbpedia.org/ontology/areaOfCatchmentQuote', 1),
#  ('http://dbpedia.org/ontology/lengthQuote', 1),
#  ('http://dbpedia.org/ontology/mgiid', 1),
#  ('http://dbpedia.org/ontology/orcidId', 1),
#  ('http://dbpedia.org/ontology/rkdArtistsId', 1)]

# %%
types_cnt.most_common()
# Out:
# [('http://www.w3.org/2001/XMLSchema#string', 6255235),
#  ('http://www.w3.org/2001/XMLSchema#gYear', 1969905),
#  ('http://www.w3.org/2001/XMLSchema#double', 1754385),
#  ('http://www.w3.org/2001/XMLSchema#date', 1530980),
#  ('http://www.w3.org/2001/XMLSchema#integer', 1328113),
#  ('http://www.w3.org/2001/XMLSchema#nonNegativeInteger', 844353),
#  ('http://www.w3.org/1999/02/22-rdf-syntax-ns#langString', 616430),
#  ('http://www.w3.org/2001/XMLSchema#positiveInteger', 45134),
#  ('http://www.w3.org/2001/XMLSchema#float', 22107),
#  ('http://www.w3.org/2001/XMLSchema#boolean', 10459),
#  ('http://dbpedia.org/datatype/engineConfiguration', 9911),
#  ('http://www.w3.org/2001/XMLSchema#gYearMonth', 547),
#  ('http://dbpedia.org/datatype/valvetrain', 491),
#  ('http://dbpedia.org/datatype/fuelType', 464),
#  ('http://www.w3.org/2001/XMLSchema#anyURI', 23)]

# %%
relations_valid_cnt.most_common()

# %%
types_valid_cnt.most_common()

# %%
save_object(relation_type_dict, "relation_type_dict")

# %%
save_object(relations_valid, "relations_valid")

# %%
save_object(relations_invalid, "relations_invalid")

# %%
save_object(types_valid, "types_valid")

# %%
save_object(types_invalid, "types_invalid")

# %%
save_object(relations_cnt, "relations_cnt")

# %%
save_object(types_cnt, "types_cnt")

# %%
save_object(relations_valid_cnt, "relations_valid_cnt")

# %%
save_object(types_valid_cnt, "types_valid_cnt")

# %%
types_int = set(['http://www.w3.org/2001/XMLSchema#positiveInteger',
                 'http://www.w3.org/2001/XMLSchema#integer',
                 'http://www.w3.org/2001/XMLSchema#nonNegativeInteger'])
save_object(types_int, "types_int")

# %%
types_float = set(['http://www.w3.org/2001/XMLSchema#float',
                   'http://www.w3.org/2001/XMLSchema#double'])
save_object(types_float, "types_float")

# %%
types_date = set(['http://www.w3.org/2001/XMLSchema#gYear',
                  'http://www.w3.org/2001/XMLSchema#date',
                  'http://www.w3.org/2001/XMLSchema#gYearMonth'])
save_object(types_date, "types_date")
